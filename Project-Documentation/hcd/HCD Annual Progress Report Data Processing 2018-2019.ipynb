# %%
import sys
import getpass
import re
from functools import partial
from tqdm import tqdm

user = getpass.getuser()
sys.dont_write_bytecode = True

sys.path.insert(0, '/Users/{}/Box/DataViz Projects/Utility Code'.format(user))

from utils_io import *  # initial imports
reload_module('utils_io')  # reload after update to utils_io.py
from utils_io import *  # reload reflects updates

#geo imports
import geopandas as gp
import folium
from geopandas.tools import geocode
from geopy.geocoders import GoogleV3
from geopy.extra.rate_limiter import RateLimiter
from geopy import Point

# %%
google_api_key = G_CREDS['dataviz_team']

# %% [markdown]
# # Housing and Community Development Annual Progress Report Data Processing <a name="top"></a>
#
# ## Background
#
# ### Annual Progress Reports
#
# **[HCD Regional Housing Needs Allocation and Housing Element Website](https://www.hcd.ca.gov/community-development/housing-element/index.shtml)**
#
# Each jurisdiction (city council or board of supervisors) must prepare an annual progress report on the jurisdiction’s status and progress in implementing its housing element. (Government Code Section 65400.)
#
# Each jurisdiction’s Annual Progress Report (APR) must be submitted to HCD and the Governor’s Office of Planning and Research (OPR) by April 1 of each year (covering the previous calendar year).
#
# New APR form and instructions - for calendar year (CY) 2018 and 2019
#
# AB 879 and SB 35 of the 2017 Housing Package, as well as AB 1486 (2019), added new data requirements for the Housing Element Annual Progress Reports (APRs). These changes are reflected in the new APR form and instructions, which are posted below.
#
# - [APR form for CY 2018 and 2019](https://www.hcd.ca.gov/community-development/housing-element/docs/Housing-Element-Annual-Progress-Report-2019.xlsm) (XLS)
# - [APR instructions for CY 2018 and 2019](https://www.hcd.ca.gov/community-development/housing-element/docs/Housing-Element-Annual-Progress-Report-Instructions-2019.pdf) (PDF)
#
# **Annual Progress Report Tables**
#
# 1. Table A - Housing Development Applications
# 2. Table A2 - New Construction, Entitled, Permits, and Completed Units
# 3. Table B - Regional Housing Needs Allocation Progress – Permitted Units Issued By Affordability
# 4. Table C - Sites Identified or Rezoned to Accommodate Shortfall Housing Need
# 5. Table D - Program Implementation Status pursuant to Government Code section 65583
# 6. Table E - Commercial Development Bonus Approved pursuant to Government Code
#
# ## Approach
#
# ## Process
#
# ## Data Sources
#
# ## Table of Contents
#
# 1. [Pre-Processing Steps](#preprocessing)
# 2. [Format Addresses](#format_address)
# 3. [Geocode Addresses](#geocode)

# %% [markdown]
# ## Create Draft Housing APR Dataset

# %%
#Get col list from current Housing APR dataset
apr_current_id = 'cypr-67hy'
get_socrata_col_list(socrata_data_id=apr_current_id)
# Out:
# [{'fieldName': 'mtc_id', 'name': 'MTC_ID', 'dataTypeName': 'text'},
#  {'fieldName': 'mtc_type', 'name': 'MTC_TYPE', 'dataTypeName': 'text'},
#  {'fieldName': 'mtc_year', 'name': 'MTC_YEAR', 'dataTypeName': 'number'},
#  {'fieldName': 'mtc_vlow_income_dr',
#   'name': 'MTC_VLOW_INCOME_DR',
#   'dataTypeName': 'number'},
#  {'fieldName': 'mtc_vlow_income_ndr',
#   'name': 'MTC_VLOW_INCOME_NDR',
#   'dataTypeName': 'number'},
#  {'fieldName': 'mtc_vlow_tot',
#   'name': 'MTC_VLOW_TOT',
#   'dataTypeName': 'number'},
#  {'fieldName': 'mtc_low_income_dr',
#   'name': 'MTC_LOW_INCOME_DR',
#   'dataTypeName': 'number'},
#  {'fieldName': 'mtc_low_income_ndr',
#   'name': 'MTC_LOW_INCOME_NDR',
#   'dataTypeName': 'number'},
#  {'fieldName': 'mtc_low_tot', 'name': 'MTC_LOW_TOT', 'dataTypeName': 'number'},
#  {'fieldName': 'mtc_mod_income_dr',
#   'name': 'MTC_MOD_INCOME_DR',
#   'dataTypeName': 'number'},
#  {'fieldName': 'mtc_mod_income_ndr',
#   'name': 'MTC_MOD_INCOME_NDR',
#   'dataTypeName': 'number'},
#  {'fieldName': 'mtc_mod_tot', 'name': 'MTC_MOD_TOT', 'dataTypeName': 'number'},
#  {'fieldName': 'mtc_above_mod_income',
#   'name': 'MTC_ABOVE_MOD_INCOME',
#   'dataTypeName': 'number'},
#  {'fieldName': 'mtc_total_units',
#   'name': 'MTC_TOTAL_UNITS',
#   'dataTypeName': 'number'},
#  {'fieldName': 'mtc_issue_dt', 'name': 'MTC_ISSUE_DT', 'dataTypeName': 'text'},
#  {'fieldName': 'mtc_no_of_units',
#   'name': 'MTC_NO_OF_UNITS',
#   'dataTypeName': 'number'},
#  {'fieldName': 'mtc_geocode_address',
#   'name': 'MTC_GEOCODE_ADDRESS',
#   'dataTypeName': 'text'},
#  {'fieldName': 'mtc_geocode_type',
#   'name': 'MTC_GEOCODE_TYPE',
#   'dataTypeName': 'text'},
#  {'fieldName': 'mtc_mapped', 'name': 'MTC_MAPPED', 'dataTypeName': 'checkbox'},
#  {'fieldName': 'mtc_lat', 'name': 'MTC_LAT', 'dataTypeName': 'number'},
#  {'fieldName': 'mtc_long', 'name': 'MTC_LONG', 'dataTypeName': 'number'},
#  {'fieldName': 'mtc_wkt', 'name': 'MTC_WKT', 'dataTypeName': 'point'},
#  {'fieldName': 'mtc_pda', 'name': 'MTC_PDA', 'dataTypeName': 'checkbox'},
#  {'fieldName': 'mtc_tpa', 'name': 'MTC_TPA', 'dataTypeName': 'checkbox'},
#  {'fieldName': 'mtc_housing_element_site',
#   'name': 'MTC_HOUSING_ELEMENT_SITE',
#   'dataTypeName': 'checkbox'},
#  {'fieldName': 'mtc_notes', 'name': 'MTC_NOTES', 'dataTypeName': 'text'},
#  {'fieldName': 'jurs_name', 'name': 'JURS_NAME', 'dataTypeName': 'text'},
#  {'fieldName': 'cnty_name', 'name': 'CNTY_NAME', 'dataTypeName': 'text'},
#  {'fieldName': 'prior_apn', 'name': 'PRIOR_APN', 'dataTypeName': 'text'},
#  {'fieldName': 'apn', 'name': 'APN', 'dataTypeName': 'text'},
#  {'fieldName': 'street_address',
#   'name': 'STREET_ADDRESS',
#   'dataTypeName': 'text'},
#  {'fieldName': 'project_name', 'name': 'PROJECT_NAME', 'dataTypeName': 'text'},
#  {'fieldName': 'jurs_tracking_id',
#   'name': 'JURS_TRACKING_ID',
#   'dataTypeName': 'text'},
#  {'fieldName': 'unit_cat_uid', 'name': 'UNIT_CAT_UID', 'dataTypeName': 'text'},
#  {'fieldName': 'tenure_uid', 'name': 'TENURE_UID', 'dataTypeName': 'text'},
#  {'fieldName': 'vlow_income_dr_con_ent_permits',
#   'name': 'VLOW_INCOME_DR_CON_ENT_PERMITS',
#   'dataTypeName': 'number'},
#  {'fieldName': 'vlow_income_ndr_con_ent_perm',
#   'name': 'VLOW_INCOME_NDR_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'low_income_dr_con_ent_permits',
#   'name': 'LOW_INCOME_DR_CON_ENT_PERMITS',
#   'dataTypeName': 'number'},
#  {'fieldName': 'low_income_ndr_con_ent_permits',
#   'name': 'LOW_INCOME_NDR_CON_ENT_PERMITS',
#   'dataTypeName': 'number'},
#  {'fieldName': 'mod_income_dr_con_ent_permits',
#   'name': 'MOD_INCOME_DR_CON_ENT_PERMITS',
#   'dataTypeName': 'number'},
#  {'fieldName': 'mod_income_ndr_con_ent_permits',
#   'name': 'MOD_INCOME_NDR_CON_ENT_PERMITS',
#   'dataTypeName': 'number'},
#  {'fieldName': 'above_mod_income_con_ent',
#   'name': 'ABOVE_MOD_INCOME_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'ent_approve_dt_con_ent_permits',
#   'name': 'ENT_APPROVE_DT_CON_ENT_PERMITS',
#   'dataTypeName': 'text'},
#  {'fieldName': 'no_of_units_issued_ent',
#   'name': 'NO_OF_UNITS_ISSUED_ENT',
#   'dataTypeName': 'number'},
#  {'fieldName': 'bp_vlow_income_dr_con_ent',
#   'name': 'BP_VLOW_INCOME_DR_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'bp_vlow_income_ndr_con_perm',
#   'name': 'BP_VLOW_INCOME_NDR_CON_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'bp_low_income_dr_con_ent',
#   'name': 'BP_LOW_INCOME_DR_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'bp_low_income_ndr_con_ent',
#   'name': 'BP_LOW_INCOME_NDR_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'bp_mod_income_dr_con_ent',
#   'name': 'BP_MOD_INCOME_DR_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'bp_mod_income_ndr_con_ent',
#   'name': 'BP_MOD_INCOME_NDR_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'bp_above_mod_income_con_ent',
#   'name': 'BP_ABOVE_MOD_INCOME_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'bp_issue_dt_con_ent_perm',
#   'name': 'BP_ISSUE_DT_CON_ENT_PERM',
#   'dataTypeName': 'text'},
#  {'fieldName': 'no_of_units_issued_bld_permits',
#   'name': 'NO_OF_UNITS_ISSUED_BLD_PERMITS',
#   'dataTypeName': 'number'},
#  {'fieldName': 'co_vlow_income_dr_con_ent',
#   'name': 'CO_VLOW_INCOME_DR_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'co_vlow_income_ndr_con_ent',
#   'name': 'CO_VLOW_INCOME_NDR_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'co_low_income_dr_con_ent',
#   'name': 'CO_LOW_INCOME_DR_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'co_low_income_ndr_con_ent',
#   'name': 'CO_LOW_INCOME_NDR_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'co_mod_income_dr_con_ent',
#   'name': 'CO_MOD_INCOME_DR_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'co_mod_income_ndr_con_ent',
#   'name': 'CO_MOD_INCOME_NDR_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'co_above_mod_income_con_ent',
#   'name': 'CO_ABOVE_MOD_INCOME_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'co_issue_dt_con_ent_perm',
#   'name': 'CO_ISSUE_DT_CON_ENT_PERM',
#   'dataTypeName': 'text'},
#  {'fieldName': 'no_of_u_iss_certi_readiness',
#   'name': 'NO_OF_U_ISS_CERTI_READINESS',
#   'dataTypeName': 'number'},
#  {'fieldName': 'extr_low_income_units_con',
#   'name': 'EXTR_LOW_INCOME_UNITS_CON_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'approve_sb35_con_ent_perm',
#   'name': 'APPROVE_SB35_CON_ENT_PERM',
#   'dataTypeName': 'checkbox'},
#  {'fieldName': 'infill_units_con_ent_perm',
#   'name': 'INFILL_UNITS_CON_ENT_PERM',
#   'dataTypeName': 'checkbox'},
#  {'fieldName': 'fin_assist_detail',
#   'name': 'FIN_ASSIST_DETAIL',
#   'dataTypeName': 'text'},
#  {'fieldName': 'dr_type_con_ent_perm',
#   'name': 'DR_TYPE_CON_ENT_PERM',
#   'dataTypeName': 'text'},
#  {'fieldName': 'no_fa_dr_con_ent_perm',
#   'name': 'NO_FA_DR_CON_ENT_PERM',
#   'dataTypeName': 'text'},
#  {'fieldName': 'term_aff_dr_con_ent_perm',
#   'name': 'TERM_AFF_DR_CON_ENT_PERM',
#   'dataTypeName': 'text'},
#  {'fieldName': 'dem_des_units_con_ent_perm',
#   'name': 'DEM_DES_UNITS_CON_ENT_PERM',
#   'dataTypeName': 'number'},
#  {'fieldName': 'dem_or_des_units_con_ent',
#   'name': 'DEM_OR_DES_UNITS_CON_ENT_PERM',
#   'dataTypeName': 'text'},
#  {'fieldName': 'dem_des_units_own_rent_con',
#   'name': 'DEM_DES_UNITS_OWN_RENT_CON_P',
#   'dataTypeName': 'text'},
#  {'fieldName': 'notes_con_ent_perm',
#   'name': 'NOTES_CON_ENT_PERM',
#   'dataTypeName': 'text'}]

# %%
apr_fields = [{'fieldName': 'mtc_id', 'name': 'MTC_ID', 'dataTypeName': 'text'},
             {'fieldName': 'mtc_type', 'name': 'MTC_TYPE', 'dataTypeName': 'text'},
             {'fieldName': 'mtc_year', 'name': 'MTC_YEAR', 'dataTypeName': 'number'},
             {'fieldName': 'mtc_vlow_income_dr',
              'name': 'MTC_VLOW_INCOME_DR',
              'dataTypeName': 'number'},
             {'fieldName': 'mtc_vlow_income_ndr',
              'name': 'MTC_VLOW_INCOME_NDR',
              'dataTypeName': 'number'},
             {'fieldName': 'mtc_vlow_tot',
              'name': 'MTC_VLOW_TOT',
              'dataTypeName': 'number'},
             {'fieldName': 'mtc_low_income_dr',
              'name': 'MTC_LOW_INCOME_DR',
              'dataTypeName': 'number'},
             {'fieldName': 'mtc_low_income_ndr',
              'name': 'MTC_LOW_INCOME_NDR',
              'dataTypeName': 'number'},
             {'fieldName': 'mtc_low_tot', 'name': 'MTC_LOW_TOT', 'dataTypeName': 'number'},
             {'fieldName': 'mtc_mod_income_dr',
              'name': 'MTC_MOD_INCOME_DR',
              'dataTypeName': 'number'},
             {'fieldName': 'mtc_mod_income_ndr',
              'name': 'MTC_MOD_INCOME_NDR',
              'dataTypeName': 'number'},
             {'fieldName': 'mtc_mod_tot', 'name': 'MTC_MOD_TOT', 'dataTypeName': 'number'},
             {'fieldName': 'mtc_above_mod_income',
              'name': 'MTC_ABOVE_MOD_INCOME',
              'dataTypeName': 'number'},
             {'fieldName': 'mtc_total_units',
              'name': 'MTC_TOTAL_UNITS',
              'dataTypeName': 'number'},
             {'fieldName': 'mtc_issue_dt', 'name': 'MTC_ISSUE_DT', 'dataTypeName': 'text'},
             {'fieldName': 'mtc_no_of_units',
              'name': 'MTC_NO_OF_UNITS',
              'dataTypeName': 'number'},
             {'fieldName': 'mtc_address_full',
             'name': 'MTC_ADDRESS_FULL',
             'dataTypeName':'text'},
             {'fieldName': 'mtc_geocode_address',
              'name': 'MTC_GEOCODE_ADDRESS',
              'dataTypeName': 'text'},
             {'fieldName': 'mtc_geocode_type',
              'name': 'MTC_GEOCODE_TYPE',
              'dataTypeName': 'text'},
             {'fieldName': 'mtc_mapped', 'name': 'MTC_MAPPED', 'dataTypeName': 'checkbox'},
             {'fieldName': 'mtc_lat', 'name': 'MTC_LAT', 'dataTypeName': 'number'},
             {'fieldName': 'mtc_long', 'name': 'MTC_LONG', 'dataTypeName': 'number'},
             {'fieldName': 'mtc_wkt', 'name': 'MTC_WKT', 'dataTypeName': 'point'},
             {'fieldName': 'mtc_pda', 'name': 'MTC_PDA', 'dataTypeName': 'checkbox'},
             {'fieldName': 'mtc_tpa', 'name': 'MTC_TPA', 'dataTypeName': 'checkbox'},
             {'fieldName': 'mtc_housing_element_site',
              'name': 'MTC_HOUSING_ELEMENT_SITE',
              'dataTypeName': 'checkbox'},
             {'fieldName': 'mtc_notes', 'name': 'MTC_NOTES', 'dataTypeName': 'text'},
             {'fieldName': 'jurs_name', 'name': 'JURS_NAME', 'dataTypeName': 'text'},
             {'fieldName': 'cnty_name', 'name': 'CNTY_NAME', 'dataTypeName': 'text'},
             {'fieldName': 'prior_apn', 'name': 'PRIOR_APN', 'dataTypeName': 'text'},
             {'fieldName': 'apn', 'name': 'APN', 'dataTypeName': 'text'},
             {'fieldName': 'street_address',
              'name': 'STREET_ADDRESS',
              'dataTypeName': 'text'},
             {'fieldName': 'project_name', 'name': 'PROJECT_NAME', 'dataTypeName': 'text'},
             {'fieldName': 'jurs_tracking_id',
              'name': 'JURS_TRACKING_ID',
              'dataTypeName': 'text'},
             {'fieldName': 'unit_cat_uid', 'name': 'UNIT_CAT_UID', 'dataTypeName': 'text'},
             {'fieldName': 'tenure_uid', 'name': 'TENURE_UID', 'dataTypeName': 'text'},
             {'fieldName': 'vlow_income_dr_con_ent_permits',
              'name': 'VLOW_INCOME_DR_CON_ENT_PERMITS',
              'dataTypeName': 'number'},
             {'fieldName': 'vlow_income_ndr_con_ent_perm',
              'name': 'VLOW_INCOME_NDR_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'low_income_dr_con_ent_permits',
              'name': 'LOW_INCOME_DR_CON_ENT_PERMITS',
              'dataTypeName': 'number'},
             {'fieldName': 'low_income_ndr_con_ent_permits',
              'name': 'LOW_INCOME_NDR_CON_ENT_PERMITS',
              'dataTypeName': 'number'},
             {'fieldName': 'mod_income_dr_con_ent_permits',
              'name': 'MOD_INCOME_DR_CON_ENT_PERMITS',
              'dataTypeName': 'number'},
             {'fieldName': 'mod_income_ndr_con_ent_permits',
              'name': 'MOD_INCOME_NDR_CON_ENT_PERMITS',
              'dataTypeName': 'number'},
             {'fieldName': 'above_mod_income_con_ent',
              'name': 'ABOVE_MOD_INCOME_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'ent_approve_dt_con_ent_permits',
              'name': 'ENT_APPROVE_DT_CON_ENT_PERMITS',
              'dataTypeName': 'text'},
             {'fieldName': 'no_of_units_issued_ent',
              'name': 'NO_OF_UNITS_ISSUED_ENT',
              'dataTypeName': 'number'},
             {'fieldName': 'bp_vlow_income_dr_con_ent',
              'name': 'BP_VLOW_INCOME_DR_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'bp_vlow_income_ndr_con_perm',
              'name': 'BP_VLOW_INCOME_NDR_CON_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'bp_low_income_dr_con_ent',
              'name': 'BP_LOW_INCOME_DR_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'bp_low_income_ndr_con_ent',
              'name': 'BP_LOW_INCOME_NDR_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'bp_mod_income_dr_con_ent',
              'name': 'BP_MOD_INCOME_DR_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'bp_mod_income_ndr_con_ent',
              'name': 'BP_MOD_INCOME_NDR_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'bp_above_mod_income_con_ent',
              'name': 'BP_ABOVE_MOD_INCOME_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'bp_issue_dt_con_ent_perm',
              'name': 'BP_ISSUE_DT_CON_ENT_PERM',
              'dataTypeName': 'text'},
             {'fieldName': 'no_of_units_issued_bld_permits',
              'name': 'NO_OF_UNITS_ISSUED_BLD_PERMITS',
              'dataTypeName': 'number'},
             {'fieldName': 'co_vlow_income_dr_con_ent',
              'name': 'CO_VLOW_INCOME_DR_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'co_vlow_income_ndr_con_ent',
              'name': 'CO_VLOW_INCOME_NDR_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'co_low_income_dr_con_ent',
              'name': 'CO_LOW_INCOME_DR_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'co_low_income_ndr_con_ent',
              'name': 'CO_LOW_INCOME_NDR_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'co_mod_income_dr_con_ent',
              'name': 'CO_MOD_INCOME_DR_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'co_mod_income_ndr_con_ent',
              'name': 'CO_MOD_INCOME_NDR_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'co_above_mod_income_con_ent',
              'name': 'CO_ABOVE_MOD_INCOME_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'co_issue_dt_con_ent_perm',
              'name': 'CO_ISSUE_DT_CON_ENT_PERM',
              'dataTypeName': 'text'},
             {'fieldName': 'no_of_u_iss_certi_readiness',
              'name': 'NO_OF_U_ISS_CERTI_READINESS',
              'dataTypeName': 'number'},
             {'fieldName': 'extr_low_income_units_con',
              'name': 'EXTR_LOW_INCOME_UNITS_CON_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'approve_sb35_con_ent_perm',
              'name': 'APPROVE_SB35_CON_ENT_PERM',
              'dataTypeName': 'checkbox'},
             {'fieldName': 'infill_units_con_ent_perm',
              'name': 'INFILL_UNITS_CON_ENT_PERM',
              'dataTypeName': 'checkbox'},
             {'fieldName': 'fin_assist_detail',
              'name': 'FIN_ASSIST_DETAIL',
              'dataTypeName': 'text'},
             {'fieldName': 'dr_type_con_ent_perm',
              'name': 'DR_TYPE_CON_ENT_PERM',
              'dataTypeName': 'text'},
             {'fieldName': 'no_fa_dr_con_ent_perm',
              'name': 'NO_FA_DR_CON_ENT_PERM',
              'dataTypeName': 'text'},
             {'fieldName': 'term_aff_dr_con_ent_perm',
              'name': 'TERM_AFF_DR_CON_ENT_PERM',
              'dataTypeName': 'text'},
             {'fieldName': 'dem_des_units_con_ent_perm',
              'name': 'DEM_DES_UNITS_CON_ENT_PERM',
              'dataTypeName': 'number'},
             {'fieldName': 'dem_or_des_units_con_ent',
              'name': 'DEM_OR_DES_UNITS_CON_ENT_PERM',
              'dataTypeName': 'text'},
             {'fieldName': 'dem_des_units_own_rent_con',
              'name': 'DEM_DES_UNITS_OWN_RENT_CON_P',
              'dataTypeName': 'text'},
             {'fieldName': 'notes_con_ent_perm',
              'name': 'NOTES_CON_ENT_PERM',
              'dataTypeName': 'text'}]

# %%
# create_socrata_dataset(dataset_name='Housing APR Data 2018-2019',
#                        dataset_desc='2018 and 2019 Annual Progress Report from California Department of Housing and Community Development',
#                        tags=['hcd','apr','housing','basis'],
#                        category=None,
#                        columns=apr_fields,
#                        row_identifier='mtc_id')
# Out:
# created dataset on Socrata with id: azj6-3imm
# {'id': 'azj6-3imm',
#  'name': 'Housing APR Data 2018-2019',
#  'assetType': 'dataset',
#  'averageRating': 0,
#  'createdAt': 1604610919,
#  'description': '2018 and 2019 Annual Progress Report from California Department of Housing and Community Development',
#  'displayType': 'table',
#  'downloadCount': 0,
#  'hideFromCatalog': False,
#  'hideFromDataJson': False,
#  'newBackend': True,
#  'numberOfComments': 0,
#  'oid': 35692949,
#  'provenance': 'official',
#  'publicationAppendEnabled': False,
#  'publicationGroup': 17752917,
#  'publicationStage': 'unpublished',
#  'rowIdentifierColumnId': 507136173,
#  'rowsUpdatedAt': 1604610919,
#  'tableId': 17752917,
#  'totalTimesRated': 0,
#  'viewCount': 0,
#  'viewLastModified': 1604610923,
#  'viewType': 'tabular',
#  'columns': [{'id': 507136173,
#    'name': 'MTC_ID',
#    'dataTypeName': 'text',
#    'fieldName': 'mtc_id',
#    'position': 1,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834394,
#    'format': {}},
#   {'id': 507136174,
#    'name': 'MTC_TYPE',
#    'dataTypeName': 'text',
#    'fieldName': 'mtc_type',
#    'position': 2,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834395,
#    'format': {}},
#   {'id': 507136175,
#    'name': 'MTC_YEAR',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_year',
#    'position': 3,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834396,
#    'format': {}},
#   {'id': 507136176,
#    'name': 'MTC_VLOW_INCOME_DR',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_vlow_income_dr',
#    'position': 4,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834397,
#    'format': {}},
#   {'id': 507136177,
#    'name': 'MTC_VLOW_INCOME_NDR',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_vlow_income_ndr',
#    'position': 5,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834398,
#    'format': {}},
#   {'id': 507136178,
#    'name': 'MTC_VLOW_TOT',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_vlow_tot',
#    'position': 6,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834399,
#    'format': {}},
#   {'id': 507136179,
#    'name': 'MTC_LOW_INCOME_DR',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_low_income_dr',
#    'position': 7,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834400,
#    'format': {}},
#   {'id': 507136180,
#    'name': 'MTC_LOW_INCOME_NDR',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_low_income_ndr',
#    'position': 8,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834401,
#    'format': {}},
#   {'id': 507136181,
#    'name': 'MTC_LOW_TOT',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_low_tot',
#    'position': 9,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834402,
#    'format': {}},
#   {'id': 507136182,
#    'name': 'MTC_MOD_INCOME_DR',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_mod_income_dr',
#    'position': 10,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834403,
#    'format': {}},
#   {'id': 507136183,
#    'name': 'MTC_MOD_INCOME_NDR',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_mod_income_ndr',
#    'position': 11,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834404,
#    'format': {}},
#   {'id': 507136184,
#    'name': 'MTC_MOD_TOT',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_mod_tot',
#    'position': 12,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834405,
#    'format': {}},
#   {'id': 507136185,
#    'name': 'MTC_ABOVE_MOD_INCOME',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_above_mod_income',
#    'position': 13,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834406,
#    'format': {}},
#   {'id': 507136186,
#    'name': 'MTC_TOTAL_UNITS',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_total_units',
#    'position': 14,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834407,
#    'format': {}},
#   {'id': 507136187,
#    'name': 'MTC_ISSUE_DT',
#    'dataTypeName': 'text',
#    'fieldName': 'mtc_issue_dt',
#    'position': 15,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834408,
#    'format': {}},
#   {'id': 507136188,
#    'name': 'MTC_NO_OF_UNITS',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_no_of_units',
#    'position': 16,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834409,
#    'format': {}},
#   {'id': 507136189,
#    'name': 'MTC_ADDRESS_FULL',
#    'dataTypeName': 'text',
#    'fieldName': 'mtc_address_full',
#    'position': 17,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834410,
#    'format': {}},
#   {'id': 507136190,
#    'name': 'MTC_GEOCODE_ADDRESS',
#    'dataTypeName': 'text',
#    'fieldName': 'mtc_geocode_address',
#    'position': 18,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834411,
#    'format': {}},
#   {'id': 507136191,
#    'name': 'MTC_GEOCODE_TYPE',
#    'dataTypeName': 'text',
#    'fieldName': 'mtc_geocode_type',
#    'position': 19,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834412,
#    'format': {}},
#   {'id': 507136192,
#    'name': 'MTC_MAPPED',
#    'dataTypeName': 'checkbox',
#    'fieldName': 'mtc_mapped',
#    'position': 20,
#    'renderTypeName': 'checkbox',
#    'tableColumnId': 121834413,
#    'format': {}},
#   {'id': 507136193,
#    'name': 'MTC_LAT',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_lat',
#    'position': 21,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834414,
#    'format': {}},
#   {'id': 507136194,
#    'name': 'MTC_LONG',
#    'dataTypeName': 'number',
#    'fieldName': 'mtc_long',
#    'position': 22,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834415,
#    'format': {}},
#   {'id': 507136195,
#    'name': 'MTC_WKT',
#    'dataTypeName': 'point',
#    'fieldName': 'mtc_wkt',
#    'position': 23,
#    'renderTypeName': 'point',
#    'tableColumnId': 121834416,
#    'format': {}},
#   {'id': 507136196,
#    'name': 'MTC_PDA',
#    'dataTypeName': 'checkbox',
#    'fieldName': 'mtc_pda',
#    'position': 24,
#    'renderTypeName': 'checkbox',
#    'tableColumnId': 121834417,
#    'format': {}},
#   {'id': 507136197,
#    'name': 'MTC_TPA',
#    'dataTypeName': 'checkbox',
#    'fieldName': 'mtc_tpa',
#    'position': 25,
#    'renderTypeName': 'checkbox',
#    'tableColumnId': 121834418,
#    'format': {}},
#   {'id': 507136198,
#    'name': 'MTC_HOUSING_ELEMENT_SITE',
#    'dataTypeName': 'checkbox',
#    'fieldName': 'mtc_housing_element_site',
#    'position': 26,
#    'renderTypeName': 'checkbox',
#    'tableColumnId': 121834419,
#    'format': {}},
#   {'id': 507136199,
#    'name': 'MTC_NOTES',
#    'dataTypeName': 'text',
#    'fieldName': 'mtc_notes',
#    'position': 27,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834420,
#    'format': {}},
#   {'id': 507136200,
#    'name': 'JURS_NAME',
#    'dataTypeName': 'text',
#    'fieldName': 'jurs_name',
#    'position': 28,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834421,
#    'format': {}},
#   {'id': 507136201,
#    'name': 'CNTY_NAME',
#    'dataTypeName': 'text',
#    'fieldName': 'cnty_name',
#    'position': 29,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834422,
#    'format': {}},
#   {'id': 507136202,
#    'name': 'PRIOR_APN',
#    'dataTypeName': 'text',
#    'fieldName': 'prior_apn',
#    'position': 30,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834423,
#    'format': {}},
#   {'id': 507136203,
#    'name': 'APN',
#    'dataTypeName': 'text',
#    'fieldName': 'apn',
#    'position': 31,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834424,
#    'format': {}},
#   {'id': 507136204,
#    'name': 'STREET_ADDRESS',
#    'dataTypeName': 'text',
#    'fieldName': 'street_address',
#    'position': 32,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834425,
#    'format': {}},
#   {'id': 507136205,
#    'name': 'PROJECT_NAME',
#    'dataTypeName': 'text',
#    'fieldName': 'project_name',
#    'position': 33,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834426,
#    'format': {}},
#   {'id': 507136206,
#    'name': 'JURS_TRACKING_ID',
#    'dataTypeName': 'text',
#    'fieldName': 'jurs_tracking_id',
#    'position': 34,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834427,
#    'format': {}},
#   {'id': 507136207,
#    'name': 'UNIT_CAT_UID',
#    'dataTypeName': 'text',
#    'fieldName': 'unit_cat_uid',
#    'position': 35,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834428,
#    'format': {}},
#   {'id': 507136208,
#    'name': 'TENURE_UID',
#    'dataTypeName': 'text',
#    'fieldName': 'tenure_uid',
#    'position': 36,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834429,
#    'format': {}},
#   {'id': 507136209,
#    'name': 'VLOW_INCOME_DR_CON_ENT_PERMITS',
#    'dataTypeName': 'number',
#    'fieldName': 'vlow_income_dr_con_ent_permits',
#    'position': 37,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834430,
#    'format': {}},
#   {'id': 507136210,
#    'name': 'VLOW_INCOME_NDR_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'vlow_income_ndr_con_ent_perm',
#    'position': 38,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834431,
#    'format': {}},
#   {'id': 507136211,
#    'name': 'LOW_INCOME_DR_CON_ENT_PERMITS',
#    'dataTypeName': 'number',
#    'fieldName': 'low_income_dr_con_ent_permits',
#    'position': 39,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834432,
#    'format': {}},
#   {'id': 507136212,
#    'name': 'LOW_INCOME_NDR_CON_ENT_PERMITS',
#    'dataTypeName': 'number',
#    'fieldName': 'low_income_ndr_con_ent_permits',
#    'position': 40,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834433,
#    'format': {}},
#   {'id': 507136213,
#    'name': 'MOD_INCOME_DR_CON_ENT_PERMITS',
#    'dataTypeName': 'number',
#    'fieldName': 'mod_income_dr_con_ent_permits',
#    'position': 41,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834434,
#    'format': {}},
#   {'id': 507136214,
#    'name': 'MOD_INCOME_NDR_CON_ENT_PERMITS',
#    'dataTypeName': 'number',
#    'fieldName': 'mod_income_ndr_con_ent_permits',
#    'position': 42,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834435,
#    'format': {}},
#   {'id': 507136215,
#    'name': 'ABOVE_MOD_INCOME_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'above_mod_income_con_ent',
#    'position': 43,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834436,
#    'format': {}},
#   {'id': 507136216,
#    'name': 'ENT_APPROVE_DT_CON_ENT_PERMITS',
#    'dataTypeName': 'text',
#    'fieldName': 'ent_approve_dt_con_ent_permits',
#    'position': 44,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834437,
#    'format': {}},
#   {'id': 507136217,
#    'name': 'NO_OF_UNITS_ISSUED_ENT',
#    'dataTypeName': 'number',
#    'fieldName': 'no_of_units_issued_ent',
#    'position': 45,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834438,
#    'format': {}},
#   {'id': 507136218,
#    'name': 'BP_VLOW_INCOME_DR_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'bp_vlow_income_dr_con_ent',
#    'position': 46,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834439,
#    'format': {}},
#   {'id': 507136219,
#    'name': 'BP_VLOW_INCOME_NDR_CON_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'bp_vlow_income_ndr_con_perm',
#    'position': 47,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834440,
#    'format': {}},
#   {'id': 507136220,
#    'name': 'BP_LOW_INCOME_DR_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'bp_low_income_dr_con_ent',
#    'position': 48,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834441,
#    'format': {}},
#   {'id': 507136221,
#    'name': 'BP_LOW_INCOME_NDR_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'bp_low_income_ndr_con_ent',
#    'position': 49,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834442,
#    'format': {}},
#   {'id': 507136222,
#    'name': 'BP_MOD_INCOME_DR_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'bp_mod_income_dr_con_ent',
#    'position': 50,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834443,
#    'format': {}},
#   {'id': 507136223,
#    'name': 'BP_MOD_INCOME_NDR_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'bp_mod_income_ndr_con_ent',
#    'position': 51,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834444,
#    'format': {}},
#   {'id': 507136224,
#    'name': 'BP_ABOVE_MOD_INCOME_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'bp_above_mod_income_con_ent',
#    'position': 52,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834445,
#    'format': {}},
#   {'id': 507136225,
#    'name': 'BP_ISSUE_DT_CON_ENT_PERM',
#    'dataTypeName': 'text',
#    'fieldName': 'bp_issue_dt_con_ent_perm',
#    'position': 53,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834446,
#    'format': {}},
#   {'id': 507136226,
#    'name': 'NO_OF_UNITS_ISSUED_BLD_PERMITS',
#    'dataTypeName': 'number',
#    'fieldName': 'no_of_units_issued_bld_permits',
#    'position': 54,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834447,
#    'format': {}},
#   {'id': 507136227,
#    'name': 'CO_VLOW_INCOME_DR_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'co_vlow_income_dr_con_ent',
#    'position': 55,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834448,
#    'format': {}},
#   {'id': 507136228,
#    'name': 'CO_VLOW_INCOME_NDR_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'co_vlow_income_ndr_con_ent',
#    'position': 56,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834449,
#    'format': {}},
#   {'id': 507136229,
#    'name': 'CO_LOW_INCOME_DR_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'co_low_income_dr_con_ent',
#    'position': 57,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834450,
#    'format': {}},
#   {'id': 507136230,
#    'name': 'CO_LOW_INCOME_NDR_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'co_low_income_ndr_con_ent',
#    'position': 58,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834451,
#    'format': {}},
#   {'id': 507136231,
#    'name': 'CO_MOD_INCOME_DR_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'co_mod_income_dr_con_ent',
#    'position': 59,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834452,
#    'format': {}},
#   {'id': 507136232,
#    'name': 'CO_MOD_INCOME_NDR_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'co_mod_income_ndr_con_ent',
#    'position': 60,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834453,
#    'format': {}},
#   {'id': 507136233,
#    'name': 'CO_ABOVE_MOD_INCOME_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'co_above_mod_income_con_ent',
#    'position': 61,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834454,
#    'format': {}},
#   {'id': 507136234,
#    'name': 'CO_ISSUE_DT_CON_ENT_PERM',
#    'dataTypeName': 'text',
#    'fieldName': 'co_issue_dt_con_ent_perm',
#    'position': 62,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834455,
#    'format': {}},
#   {'id': 507136235,
#    'name': 'NO_OF_U_ISS_CERTI_READINESS',
#    'dataTypeName': 'number',
#    'fieldName': 'no_of_u_iss_certi_readiness',
#    'position': 63,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834456,
#    'format': {}},
#   {'id': 507136236,
#    'name': 'EXTR_LOW_INCOME_UNITS_CON_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'extr_low_income_units_con',
#    'position': 64,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834457,
#    'format': {}},
#   {'id': 507136237,
#    'name': 'APPROVE_SB35_CON_ENT_PERM',
#    'dataTypeName': 'checkbox',
#    'fieldName': 'approve_sb35_con_ent_perm',
#    'position': 65,
#    'renderTypeName': 'checkbox',
#    'tableColumnId': 121834458,
#    'format': {}},
#   {'id': 507136238,
#    'name': 'INFILL_UNITS_CON_ENT_PERM',
#    'dataTypeName': 'checkbox',
#    'fieldName': 'infill_units_con_ent_perm',
#    'position': 66,
#    'renderTypeName': 'checkbox',
#    'tableColumnId': 121834459,
#    'format': {}},
#   {'id': 507136239,
#    'name': 'FIN_ASSIST_DETAIL',
#    'dataTypeName': 'text',
#    'fieldName': 'fin_assist_detail',
#    'position': 67,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834460,
#    'format': {}},
#   {'id': 507136240,
#    'name': 'DR_TYPE_CON_ENT_PERM',
#    'dataTypeName': 'text',
#    'fieldName': 'dr_type_con_ent_perm',
#    'position': 68,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834461,
#    'format': {}},
#   {'id': 507136241,
#    'name': 'NO_FA_DR_CON_ENT_PERM',
#    'dataTypeName': 'text',
#    'fieldName': 'no_fa_dr_con_ent_perm',
#    'position': 69,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834462,
#    'format': {}},
#   {'id': 507136242,
#    'name': 'TERM_AFF_DR_CON_ENT_PERM',
#    'dataTypeName': 'text',
#    'fieldName': 'term_aff_dr_con_ent_perm',
#    'position': 70,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834463,
#    'format': {}},
#   {'id': 507136243,
#    'name': 'DEM_DES_UNITS_CON_ENT_PERM',
#    'dataTypeName': 'number',
#    'fieldName': 'dem_des_units_con_ent_perm',
#    'position': 71,
#    'renderTypeName': 'number',
#    'tableColumnId': 121834464,
#    'format': {}},
#   {'id': 507136244,
#    'name': 'DEM_OR_DES_UNITS_CON_ENT_PERM',
#    'dataTypeName': 'text',
#    'fieldName': 'dem_or_des_units_con_ent',
#    'position': 72,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834465,
#    'format': {}},
#   {'id': 507136245,
#    'name': 'DEM_DES_UNITS_OWN_RENT_CON_P',
#    'dataTypeName': 'text',
#    'fieldName': 'dem_des_units_own_rent_con',
#    'position': 73,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834466,
#    'format': {}},
#   {'id': 507136246,
#    'name': 'NOTES_CON_ENT_PERM',
#    'dataTypeName': 'text',
#    'fieldName': 'notes_con_ent_perm',
#    'position': 74,
#    'renderTypeName': 'text',
#    'tableColumnId': 121834467,
#    'format': {}}],
#  'metadata': {'rowIdentifier': 507136173},
#  'owner': {'id': 'rk9g-f4it',
#   'displayName': 'Joshua Croff',
#   'profileImageUrlLarge': '/api/users/rk9g-f4it/profile_images/LARGE',
#   'profileImageUrlMedium': '/api/users/rk9g-f4it/profile_images/THUMB',
#   'profileImageUrlSmall': '/api/users/rk9g-f4it/profile_images/TINY',
#   'screenName': 'Joshua Croff',
#   'type': 'interactive',
#   'userSegment': 'site_member',
#   'flags': ['acceptedEula', 'mayBeStoriesCoOwner', 'siteMember']},
#  'permissions': {'scope': 'private',
#   'accessLevels': [{'name': 'viewer', 'version': 'published'},
#    {'name': 'owner', 'version': 'all'}],
#   'users': [{'id': 'rk9g-f4it',
#     'displayName': 'Joshua Croff',
#     'email': 'jcroff@bayareametro.gov',
#     'type': 'interactive',
#     'accessLevels': [{'name': 'current_owner', 'version': 'all'}]}]},
#  'query': {},
#  'rights': ['read',
#   'write',
#   'add',
#   'delete',
#   'grant',
#   'add_column',
#   'remove_column',
#   'update_column',
#   'update_view',
#   'delete_view',
#   'transfer_ownership',
#   'manage_provenance'],
#  'tableAuthor': {'id': 'rk9g-f4it',
#   'displayName': 'Joshua Croff',
#   'profileImageUrlLarge': '/api/users/rk9g-f4it/profile_images/LARGE',
#   'profileImageUrlMedium': '/api/users/rk9g-f4it/profile_images/THUMB',
#   'profileImageUrlSmall': '/api/users/rk9g-f4it/profile_images/TINY',
#   'screenName': 'Joshua Croff',
#   'type': 'interactive',
#   'userSegment': 'site_member',
#   'flags': ['acceptedEula', 'mayBeStoriesCoOwner', 'siteMember']},
#  'tags': ['hcd', 'apr', 'housing', 'basis'],
#  'flags': ['default']}

# %%
apr_new_id = 'azj6-3imm'

# %% [markdown]
# ## Pre-Processing Steps <a name="preprocessing"></a>
# **[Skip to next step](#format_address)**

# %%
#set working directory
work_dir = os.path.join('/Users',
                       user,
                       'Box',
                       'DataViz Projects',
                       'Data Services',
                       'Housing',
                       '2020')

# %%
#list files in working directory
os.listdir(os.path.join(work_dir,
                       '2019 Original APRs'))
# Out:
# ['Extracts',
#  'ORIGINAL_Table_A2_Report_with_Data_Dictionary.xlsx',
#  'ORIGINAL_Table_A_2018_2019.xlsx',
#  'ORIGINAL_Table_D_Report.xlsx',
#  'Table_A2_Report_Address_Lat_Long.xlsx',
#  'Table_A2_Report_Lat_Long_Google.csv']

# %%
#read in Table A2 (Annual Progress Report Table 2018-2019)
apr_df = pd.read_excel(os.path.join(work_dir,
                                  '2019 Original APRs',
                                 'ORIGINAL_Table_A2_Report_with_Data_Dictionary.xlsx'),
                      sheet_name='Table A2 Report')

# %%
apr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181271 entries, 0 to 181270
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   JURS_NAME                    181269 non-null  object
#  1   CNTY_NAME                    181270 non-null  object
#  2   YEAR                         181270 non-null  float64
#  3   PRIOR_APN                    19327 non-null   object
#  4   APN                          179827 non-null  object
#  5   STREET_ADDRESS               179115 non-null  object
#  6   PROJECT_NAME                 79978 non-null   object
#  7   JURS_TRACKING_ID             147489 non-null  object
#  8   UNIT_CAT_DESC                181268 non-null  object
#  9   TENURE                       181268 non-null  object
#  10  VLOW_INCOME_DR               181268 non-null  float64
#  11  VLOW_INCOME_NDR              181268 non-null  float64
#  12  LOW_INCOME_DR                181268 non-null  float64
#  13  LOW_INCOME_NDR               181268 non-null  object
#  14  MOD_INCOME_DR                181268 non-null  float64
#  15  MOD_INCOME_NDR               181268 non-null  float64
#  16  ABOVE_MOD_INCOME             181268 non-null  float64
#  17  ENT_APPROVE_DT               29078 non-null   object
#  18  NO_ENTITLEMENTS              181268 non-null  float64
#  19  BP_VLOW_INCOME_DR            181268 non-null  float64
#  20  BP_VLOW_INCOME_NDR           181268 non-null  float64
#  21  BP_LOW_INCOME_DR             181268 non-null  float64
#  22  BP_LOW_INCOME_NDR            181267 non-null  float64
#  23  BP_MOD_INCOME_DR             181268 non-null  float64
#  24  BP_MOD_INCOME_NDR            181267 non-null  float64
#  25  BP_ABOVE_MOD_INCOME          181268 non-null  object
#  26  BP_ISSUE_DT                  125346 non-null  object
#  27  NO_BILDING_PERMITS           181267 non-null  float64
#  28  CO_VLOW_INCOME_DR            181267 non-null  float64
#  29  CO_VLOW_INCOME_NDR           181268 non-null  object
#  30  CO_LOW_INCOME_DR             181267 non-null  float64
#  31  CO_LOW_INCOME_NDR            181267 non-null  float64
#  32  CO_MOD_INCOME_DR             181267 non-null  float64
#  33  CO_MOD_INCOME_NDR            181267 non-null  float64
#  34  CO_ABOVE_MOD_INCOME          181267 non-null  float64
#  35  CO_ISSUE_DT                  79602 non-null   object
#  36  NO_OTHER_FORMS_OF_READINESS  181267 non-null  float64
#  37  EXTR_LOW_INCOME_UNITS        27263 non-null   float64
#  38  APPROVE_SB35                 181267 non-null  object
#  39  INFILL_UNITS                 78930 non-null   object
#  40  FIN_ASSIST_NAME              3538 non-null    object
#  41  DR_TYPE                      4383 non-null    object
#  42  NO_FA_DR                     28451 non-null   object
#  43  TERM_AFF_DR                  2844 non-null    object
#  44  DEM_DES_UNITS                5897 non-null    float64
#  45  DEM_OR_DES_UNITS             3923 non-null    object
#  46  DEM_DES_UNITS_OWN_RENT       3060 non-null    object
#  47  NOTES                        14956 non-null   object
# dtypes: float64(24), object(24)
# memory usage: 66.4+ MB

# %%
apr_df.head(5)
# Out:
#   JURS_NAME       CNTY_NAME    YEAR PRIOR_APN  APN  \
# 0  ADELANTO  SAN BERNARDINO  2019.0       NaN  TBD
# 1  ADELANTO  SAN BERNARDINO  2019.0       NaN  TBD
# 2  ADELANTO  SAN BERNARDINO  2019.0       NaN  TBD
# 3  ADELANTO  SAN BERNARDINO  2019.0       NaN  TBD
# 4  ADELANTO  SAN BERNARDINO  2019.0       NaN  TBD
#
#                STREET_ADDRESS                                PROJECT_NAME  \
# 0    10514 PAMPAS CT, Lot: 93                                   DR HORTON
# 1  10515 CHEVRON CT, Lot: 129                                   DR HORTON
# 2  10524 CHEVRON CT, Lot: 113                                   DR HORTON
# 3  10536 CHEVRON CT, Lot: 114                                   DR HORTON
# 4   10537 PAMPAS CT, Lot: 109  D R HORTON LOS ANGELES HOLDING COMPANY INC
#
#   JURS_TRACKING_ID                UNIT_CAT_DESC TENURE  ...  APPROVE_SB35  \
# 0              NaN  Single-Family Detached Unit  Owner  ...             N
# 1              NaN  Single-Family Detached Unit  Owner  ...             N
# 2              NaN  Single-Family Detached Unit  Owner  ...             N
# 3              NaN  Single-Family Detached Unit  Owner  ...             N
# 4              NaN  Single-Family Detached Unit  Owner  ...             N
#
#    INFILL_UNITS  FIN_ASSIST_NAME DR_TYPE  NO_FA_DR  TERM_AFF_DR  \
# 0           NaN              NaN     NaN       NaN          NaN
# 1           NaN              NaN     NaN       NaN          NaN
# 2           NaN              NaN     NaN       NaN          NaN
# 3           NaN              NaN     NaN       NaN          NaN
# 4           NaN              NaN     NaN       NaN          NaN
#
#    DEM_DES_UNITS DEM_OR_DES_UNITS  DEM_DES_UNITS_OWN_RENT  NOTES
# 0            NaN              NaN                     NaN    NaN
# 1            NaN              NaN                     NaN    NaN
# 2            NaN              NaN                     NaN    NaN
# 3            NaN              NaN                     NaN    NaN
# 4            NaN              NaN                     NaN    NaN
#
# [5 rows x 48 columns]

# %%
apr_df['CNTY_NAME'].unique()
# Out:
# array(['SAN BERNARDINO', 'LOS ANGELES', 'ALAMEDA', 'ORANGE', 'ALPINE',
#        'MODOC', 'AMADOR', 'NAPA', 'SHASTA', 'CALAVERAS', 'CONTRA COSTA',
#        'HUMBOLDT', 'SAN LUIS OBISPO', 'KERN', 'SAN MATEO', 'PLACER',
#        'KINGS', 'RIVERSIDE', 'MARIN', 'SOLANO', 'BUTTE', 'INYO',
#        'IMPERIAL', 'SANTA BARBARA', 'VENTURA', 'SANTA CLARA',
#        'SANTA CRUZ', 'SAN DIEGO', 'STANISLAUS', 'MADERA', 'SACRAMENTO',
#        'LAKE', 'SONOMA', 'FRESNO', 'COLUSA', 'TEHAMA', 'DEL NORTE',
#        'YOLO', 'TULARE', 'MERCED', 'SISKIYOU', 'EL DORADO', 'SAN JOAQUIN',
#        'MENDOCINO', 'GLENN', 'NEVADA', 'MONTEREY', 'SAN BENITO', 'SUTTER',
#        'MONO', 'MARIPOSA', 'YUBA', 'PLUMAS', 'SAN FRANCISCO', nan,
#        'TUOLUMNE', 'LASSEN', 'TRINITY', 'SIERRA', 0], dtype=object)

# %%
#filter to include only Bay Area Counties
bay_area = ['ALAMEDA',
            'CONTRA COSTA',
            'MARIN',
            'NAPA',
            'SAN FRANCISCO',
            'SAN MATEO',
            'SANTA CLARA',
            'SOLANO',
            'SONOMA']

# %%
apr_bay_area = apr_df[apr_df['CNTY_NAME'].isin(bay_area)].copy()

# %%
apr_bay_area['CNTY_NAME'].unique()
# Out:
# array(['ALAMEDA', 'NAPA', 'CONTRA COSTA', 'SAN MATEO', 'MARIN', 'SOLANO',
#        'SANTA CLARA', 'SONOMA', 'SAN FRANCISCO'], dtype=object)

# %% [markdown]
# **[Back to Top](#top)**
#
# **[Back to Section Top](#preprocessing)**

# %% [markdown]
# ## Format Addresses <a name='format_address'></a>
#
# **[Skip to next step](#geocode)**

# %%
#Check a sample of records to review street address patterns
apr_bay_area[['JURS_NAME','STREET_ADDRESS']].sample(n=20)
# Out:
#                  JURS_NAME                         STREET_ADDRESS
# 171585  SANTA CLARA COUNTY               San Jose, CA  95127-2927
# 22043               GILROY                     1611 CASTLEWOOD PL
# 82399             SAN JOSE                       1359 YOSEMITE AV
# 16450            FAIRFIELD                         4417 CANCUN DR
# 140280          MENLO PARK                       797 Live Oak Ave
# 175708           SUNNYVALE                   556  SAN MARTIN TR 2
# 174414       SONOMA COUNTY      9121 RED HILL CT, Cotati CA 94931
# 107675           DALY CITY                         34 Baldwin Ave
# 4105             BRENTWOOD                           841 WALSH ST
# 107926            DANVILLE                         42 William Ct.
# 108864              DUBLIN                    2926 TULARE HILL DR
# 168675            SAN JOSE                 112 AGUSTIN NARVAEZ ST
# 107632           DALY CITY                          1653 Annie St
# 23836              HAYWARD                  25265 Parklane DR 108
# 53008              OAKLAND        730 HENRY ST, Oakland, CA 94607
# 87932           SANTA ROSA                        990 BRUNELLO DR
# 91287            SUNNYVALE                     1119  GIANNITSA TR
# 168530            SAN JOSE                           565 MINOR AV
# 62582            RIO VISTA  2274 STARS DRIVE, Rio Vista, CA 94571
# 149937       PLEASANT HILL               550 Tananger Heights Ln.

# %%
#Set street address to uppercase
apr_bay_area['STREET_ADDRESS'] = apr_bay_area['STREET_ADDRESS'].str.upper()

# %%
#Regex pattern for matching state, and zip of different formats
regex_pattern = r'( CA \d{5}-\d{4}|CA, \d{5}-\d{4}| CA \d{5}| CA, \d{5}|, CA \d{5}|, CA, \d{5}-\d{4}|, CA, \d{5}|CA$|, CA$|\d{5}$|\d{5}-\d{4}$)'

# %%
#Check street address for state and zipcode
apr_bay_area_state_zip = apr_bay_area[apr_bay_area['STREET_ADDRESS'].str.contains(regex_pattern,na=False)]
# Out:
# /Users/jcroff/anaconda3/envs/geo_env/lib/python3.7/site-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
apr_bay_area_state_zip.sample(n=20)
# Out:
#                   JURS_NAME     CNTY_NAME    YEAR    PRIOR_APN            APN  \
# 89222         SONOMA COUNTY        SONOMA  2019.0          NaN    029-160-023
# 144613              OAKLAND       ALAMEDA  2018.0          NaN  014 123100900
# 145087              OAKLAND       ALAMEDA  2018.0          NaN  044 496000200
# 53495               OAKLAND       ALAMEDA  2019.0          NaN  029A130701100
# 53434               OAKLAND       ALAMEDA  2019.0          NaN  026 081400900
# 10644   CONTRA COSTA COUNTY  CONTRA COSTA  2019.0          NaN       31240015
# 89434         SONOMA COUNTY        SONOMA  2019.0          NaN    053-051-041
# 106882  CONTRA COSTA COUNTY  CONTRA COSTA  2018.0          NaN      206800056
# 62670             RIO VISTA        SOLANO  2019.0  176-455-050    176-455-050
# 53520               OAKLAND       ALAMEDA  2019.0          NaN  030 195600700
# 53608               OAKLAND       ALAMEDA  2019.0          NaN  036 249702800
# 89699         SONOMA COUNTY        SONOMA  2019.0          NaN    058-310-038
# 53049               OAKLAND       ALAMEDA  2019.0          NaN  006 003104400
# 10545   CONTRA COSTA COUNTY  CONTRA COSTA  2019.0          NaN      198071005
# 86395    SANTA CLARA COUNTY   SANTA CLARA  2019.0          NaN       77602028
# 10488   CONTRA COSTA COUNTY  CONTRA COSTA  2019.0          NaN      188232042
# 10499   CONTRA COSTA COUNTY  CONTRA COSTA  2019.0          NaN      192011047
# 53223               OAKLAND       ALAMEDA  2019.0          NaN  014 119502000
# 31064             LIVERMORE       ALAMEDA  2019.0          NaN    99045402100
# 89553         SONOMA COUNTY        SONOMA  2019.0          NaN    058-171-002
#
#                                      STREET_ADDRESS          PROJECT_NAME  \
# 89222      4385 PARKER HILL RD, SANTA ROSA CA 95404                   NaN
# 144613          5245 SHAFTER AVE, OAKLAND, CA 94618                   NaN
# 145087             1245 97TH AVE, OAKLAND, CA 94603                   NaN
# 53495           4069 LINCOLN AVE, OAKLAND, CA 94602                   NaN
# 53434             2765 GARDEN ST, OAKLAND, CA 94601                   NaN
# 10644             36 SEAWARD BETHEL ISLAND CA 94511                   NaN
# 89434          2000 TRINITY RD, GLEN ELLEN CA 95442                   NaN
# 106882                423 VENDEEN DANVILLE CA 94526                   NaN
# 62670         1966 FREEDOM WAY, RIO VISTA, CA 94571        Encore Liberty
# 53520            4334 PAMPAS AVE, OAKLAND, CA 94619                   NaN
# 53608         5336 NORMANDIE AVE, OAKLAND, CA 94619                   NaN
# 89699   320 PACIFIC HEIGHTS DR, SANTA ROSA CA 95403                   NaN
# 53049               1014 PINE ST, OAKLAND, CA 94607                   NaN
# 10545             1313 DANVILLE ALAMO CA 94507-1915                   NaN
# 86395                   OSBORNE CT, MORGAN HILL, CA                   NaN
# 10488                         62 CREST AVE ALAMO CA                   NaN
# 10499           1415 LIVORNA RD ALAMO CA 94507-1103                   NaN
# 53223             5316 MARKET ST, OAKLAND, CA 94608                   NaN
# 31064              2432 MARBURY RD, LIVERMORE 94550  Stonich attached ADU
# 89553           33 RAMSGATE CT, SANTA ROSA CA 95403                   NaN
#
#        JURS_TRACKING_ID                UNIT_CAT_DESC  TENURE  ...  \
# 89222        BLD19-1577  Single-Family Detached Unit   Owner  ...
# 144613        DRX180514      Accessory Dwelling Unit  Renter  ...
# 145087        RB1802843      Accessory Dwelling Unit  Renter  ...
# 53495        RBC1903690      Accessory Dwelling Unit  Renter  ...
# 53434        RBC1900254      Accessory Dwelling Unit  Renter  ...
# 10644      BIR19-000197  Single-Family Detached Unit   Owner  ...
# 89434        BLD18-6555  Single-Family Detached Unit   Owner  ...
# 106882     BIR18-008833  Single-Family Detached Unit   Owner  ...
# 62670        PB 19-6354  Single-Family Detached Unit   Owner  ...
# 53520         RB1705616  Single-Family Detached Unit   Owner  ...
# 53608         DRX192019      Accessory Dwelling Unit  Renter  ...
# 89699        BLD18-3192  Single-Family Detached Unit   Owner  ...
# 53049        RBC1902440      Accessory Dwelling Unit  Renter  ...
# 10545      BIR19-002467      Accessory Dwelling Unit  Renter  ...
# 86395        2018-49296      Accessory Dwelling Unit  Renter  ...
# 10488      BIR17-007273  Single-Family Detached Unit   Owner  ...
# 10499      CDSU19-00049      Accessory Dwelling Unit  Renter  ...
# 53223         DRX192014      Accessory Dwelling Unit  Renter  ...
# 31064         ADU18-035      Accessory Dwelling Unit  Renter  ...
# 89553        BLD18-3033  Single-Family Detached Unit   Owner  ...
#
#         APPROVE_SB35  INFILL_UNITS  FIN_ASSIST_NAME DR_TYPE  \
# 89222              N           NaN              NaN     NaN
# 144613             N             Y              NaN     NaN
# 145087             N             Y              NaN     NaN
# 53495              N             Y              NaN     NaN
# 53434              N             Y              NaN     NaN
# 10644              N           NaN              NaN     NaN
# 89434              N           NaN              NaN     NaN
# 106882             N           NaN              NaN     NaN
# 62670              N             N              NaN     NaN
# 53520              N             Y              NaN     NaN
# 53608              N             Y              NaN     NaN
# 89699              N           NaN              NaN     NaN
# 53049              N             Y              NaN     NaN
# 10545              N           NaN              NaN     NaN
# 86395              N           NaN              NaN     NaN
# 10488              N           NaN              NaN     NaN
# 10499              N           NaN              NaN     NaN
# 53223              N             Y              NaN     NaN
# 31064              N           NaN              NaN     NaN
# 89553              N           NaN              NaN     NaN
#
#                                                NO_FA_DR  TERM_AFF_DR  \
# 89222                                               NaN          NaN
# 144613                                              NaN          NaN
# 145087                                              NaN          NaN
# 53495                                               NaN          NaN
# 53434                                               NaN          NaN
# 10644                                               NaN          NaN
# 89434                                               NaN          NaN
# 106882                                              NaN          NaN
# 62670                                               NaN          NaN
# 53520                                               NaN          NaN
# 53608                                               NaN          NaN
# 89699                                               NaN          NaN
# 53049                                               NaN          NaN
# 10545                                               NaN          NaN
# 86395                                       rent survey          NaN
# 10488                                               NaN          NaN
# 10499                                               NaN          NaN
# 53223                                               NaN          NaN
# 31064   ADUs are rented in Livermore at moderate prices          NaN
# 89553                                               NaN          NaN
#
#         DEM_DES_UNITS DEM_OR_DES_UNITS  DEM_DES_UNITS_OWN_RENT  \
# 89222             1.0        Destroyed                       O
# 144613            NaN              NaN                     NaN
# 145087            NaN              NaN                     NaN
# 53495             NaN              NaN                     NaN
# 53434             NaN              NaN                     NaN
# 10644             NaN              NaN                     NaN
# 89434             1.0        Destroyed                       O
# 106882            NaN              NaN                     NaN
# 62670             NaN              NaN                     NaN
# 53520             NaN              NaN                     NaN
# 53608             NaN              NaN                     NaN
# 89699             1.0        Destroyed                       O
# 53049             NaN              NaN                     NaN
# 10545             NaN              NaN                     NaN
# 86395             NaN              NaN                     NaN
# 10488             NaN              NaN                     NaN
# 10499             NaN              NaN                     NaN
# 53223             NaN              NaN                     NaN
# 31064             NaN              NaN                     NaN
# 89553             1.0        Destroyed                       O
#
#                                                     NOTES
# 89222   2017 COMPLEX FIRE - SFD 1877 SQFT: GARAGE 1058...
# 144613                                                NaN
# 145087  To convert illegal conversion into two dwellin...
# 53495   To convert lower level of existing SFD into 1,...
# 53434   775 basement conversion in SFD into secondary ...
# 10644                                                 NaN
# 89434   2017 COMPLEX FIRE CABIN 881 SQFT, 354 DECKS EV...
# 106882                                                NaN
# 62670                                                 NaN
# 53520   Construct new two-story 2,512 SF SFD to includ...
# 53608   This is a DRX for a 462 square-foot ADU / seco...
# 89699   2017 COMPLEX FIRE - REBUILD 1944 SF SFD W/ 651...
# 53049   To construct new two-story 1,885-sq. ft. SFD, ...
# 10545                                                 NaN
# 86395                                                 NaN
# 10488                                                 NaN
# 10499                                                 NaN
# 53223   New ADU in the new basement of an existing hom...
# 31064                                                 NaN
# 89553   2017 COMPLEX FIRE 1641 SF SFD, 471 SF GARAGE &...
#
# [20 rows x 48 columns]

# %%
#Test regex pattern to replace street address with string not containing state and zip on subset
apr_bay_area_state_zip['STREET_ADDRESS'].str.replace(regex_pattern,'',regex=True)
# Out:
# 10322          1540 FRED JACKSON RICHMOND
# 10323              1751 ORCHARD BRENTWOOD
# 10324          2681 WALNUT BLVD BRENTWOOD
# 10325                1311 PAYNE BRENTWOOD
# 10326               7760 BYRON HWY BYRON
#                        ...
# 174721            182 SOUNDING, SEA RANCH
# 174722     183 BROAD REACH, THE SEA RANCH
# 174723     285 BROAD REACH, THE SEA RANCH
# 174724    42317 FORECASTLE, THE SEA RANCH
# 174725    40420 LEEWARD RD, THE SEA RANCH
# Name: STREET_ADDRESS, Length: 3949, dtype: object

# %%
#Remove state and zipcode from address
apr_bay_area['STREET_ADDRESS_FMT'] = apr_bay_area['STREET_ADDRESS'].str.replace(regex_pattern,'',regex=True)

# %%
#Check street address for state and zipcode
apr_bay_area[['STREET_ADDRESS','STREET_ADDRESS_FMT']][(apr_bay_area['STREET_ADDRESS']
                                                       .str.contains(regex_pattern,na=False))]
# Out:
# /Users/jcroff/anaconda3/envs/geo_env/lib/python3.7/site-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#                                   STREET_ADDRESS  \
# 10322   1540 FRED JACKSON RICHMOND CA 94801-1535
# 10323            1751 ORCHARD BRENTWOOD CA 94513
# 10324   2681 WALNUT BLVD BRENTWOOD CA 94513-4402
# 10325         1311 PAYNE BRENTWOOD CA 94513-4553
# 10326                    7760 BYRON HWY BYRON CA
# ...                                          ...
# 174721          182 SOUNDING, SEA RANCH CA 95497
# 174722   183 BROAD REACH, THE SEA RANCH CA 95497
# 174723   285 BROAD REACH, THE SEA RANCH CA 95497
# 174724  42317 FORECASTLE, THE SEA RANCH CA 95497
# 174725  40420 LEEWARD RD, THE SEA RANCH CA 95497
#
#                      STREET_ADDRESS_FMT
# 10322        1540 FRED JACKSON RICHMOND
# 10323            1751 ORCHARD BRENTWOOD
# 10324        2681 WALNUT BLVD BRENTWOOD
# 10325              1311 PAYNE BRENTWOOD
# 10326             7760 BYRON HWY BYRON
# ...                                 ...
# 174721          182 SOUNDING, SEA RANCH
# 174722   183 BROAD REACH, THE SEA RANCH
# 174723   285 BROAD REACH, THE SEA RANCH
# 174724  42317 FORECASTLE, THE SEA RANCH
# 174725  40420 LEEWARD RD, THE SEA RANCH
#
# [3949 rows x 2 columns]

# %%
#Create subset df of street addresses containing zip codes
zip_regex = r'(\d{5}$|\d{5}-\d{4}$)'
apr_bay_area_zip = apr_bay_area[['STREET_ADDRESS']][(apr_bay_area['STREET_ADDRESS']
                                  .str.contains(zip_regex,na=False))]
# Out:
# /Users/jcroff/anaconda3/envs/geo_env/lib/python3.7/site-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
#Check zipcodes 
apr_bay_area_zip.sample(n=10)
# Out:
#                                            STREET_ADDRESS
# 53120                      880 31ST ST, OAKLAND, CA 94608
# 144782                   515 HADDON RD, OAKLAND, CA 94606
# 89467                  100 SYLVIA DR, GLEN ELLEN CA 95442
# 89984               23580 FORT ROSS RD, CAZADERO CA 95421
# 144841                   2119 34TH AVE, OAKLAND, CA 94601
# 169773  12 TURTLE BAY PL, UNIT 2ND, SAN MATEO, CA 9440...
# 10647                   60 SEAWARD BETHEL ISLAND CA 94511
# 171613                         SAN MARTIN, CA  95046-0000
# 62580               2258 STARS DRIVE, RIO VISTA, CA 94571
# 174560      5970 VINE HILL SCHOOL RD, SEBASTOPOL CA 95472

# %%
#Test extract with regex on subset of records
apr_bay_area_zip['STREET_ADDRESS'].str.extract(zip_regex)

# %%
#Set new zip column value using zip regex 
apr_bay_area['MTC_ZIP'] = apr_bay_area['STREET_ADDRESS'].str.extract(zip_regex)

# %%
#Review records that match regex 
apr_bay_area[['STREET_ADDRESS','MTC_ZIP']][(apr_bay_area['STREET_ADDRESS']
                                  .str.contains(zip_regex,na=False))]
# Out:
# /Users/jcroff/anaconda3/envs/geo_env/lib/python3.7/site-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#                                   STREET_ADDRESS     MTC_ZIP
# 10322   1540 FRED JACKSON RICHMOND CA 94801-1535  94801-1535
# 10323            1751 ORCHARD BRENTWOOD CA 94513       94513
# 10324   2681 WALNUT BLVD BRENTWOOD CA 94513-4402  94513-4402
# 10325         1311 PAYNE BRENTWOOD CA 94513-4553  94513-4553
# 10327   25987 MARSH CREEK RD BYRON CA 94513-4315  94513-4315
# ...                                          ...         ...
# 174721          182 SOUNDING, SEA RANCH CA 95497       95497
# 174722   183 BROAD REACH, THE SEA RANCH CA 95497       95497
# 174723   285 BROAD REACH, THE SEA RANCH CA 95497       95497
# 174724  42317 FORECASTLE, THE SEA RANCH CA 95497       95497
# 174725  40420 LEEWARD RD, THE SEA RANCH CA 95497       95497
#
# [3383 rows x 2 columns]

# %% [markdown]
# **[Back to Top](#top)**
#
# **[Back to Section Top](#format_address)**

# %% [markdown]
# ## Geocode Addresses <a name='geocode'></a>
#
# **[Skip to next step](#income_categories)**

# %%
#Create concatenated address field 
apr_bay_area['MTC_ADDRESS_FULL'] =  (apr_bay_area['STREET_ADDRESS_FMT'] + 
                                         ', ' + 
                                         apr_bay_area['JURS_NAME'] +
                                        ', ' +
                                        'CA ' +
                                        apr_bay_area['MTC_ZIP'].fillna('') +
                                        ', USA')

# %%
#Return a sample of addresses to review format
apr_bay_area[['STREET_ADDRESS','JURS_NAME','STREET_ADDRESS_FMT','MTC_ZIP','MTC_ADDRESS_FULL']].sample(n=20)
# Out:
#                              STREET_ADDRESS            JURS_NAME  \
# 175470                     846  COTATI TR 9            SUNNYVALE
# 79363                        562 FILBERT ST        SAN FRANCISCO
# 82315                          985 MORSE ST             SAN JOSE
# 99138                5517 PINNACLE VIEW WAY              ANTIOCH
# 46763                   125 EDGEWOOD AVENUE         MARIN COUNTY
# 22070                       7040 KIRIGIN WY               GILROY
# 173584                      13151 MCDOVE ST             SARATOGA
# 3907                        2291 RESERVE DR            BRENTWOOD
# 89127                    234 NEWCOMB STREET               SONOMA
# 95171                      443 POTTERS LANE            VACAVILLE
# 145542                     375 HANSFORD WAY               OAKLEY
# 106949  5926 ALPINE SAN PABLO CA 94806-4107  CONTRA COSTA COUNTY
# 51514                        105  ORTEGA AV        MOUNTAIN VIEW
# 173249                                  NaN           SANTA ROSA
# 53001       1412 12TH ST, OAKLAND, CA 94607              OAKLAND
# 95271                     484 JERRYLEE ROAD            VACAVILLE
# 57011                    1 DALEWOOD TERRACE               ORINDA
# 86221                   840 CIVIC CENTER DR          SANTA CLARA
# 88017                  4628 BENNETT VIEW DR           SANTA ROSA
# 173681                     835 FIRST STREET           SEBASTOPOL
#
#             STREET_ADDRESS_FMT     MTC_ZIP  \
# 175470        846  COTATI TR 9         NaN
# 79363           562 FILBERT ST         NaN
# 82315             985 MORSE ST         NaN
# 99138   5517 PINNACLE VIEW WAY         NaN
# 46763      125 EDGEWOOD AVENUE         NaN
# 22070          7040 KIRIGIN WY         NaN
# 173584         13151 MCDOVE ST         NaN
# 3907           2291 RESERVE DR         NaN
# 89127       234 NEWCOMB STREET         NaN
# 95171         443 POTTERS LANE         NaN
# 145542        375 HANSFORD WAY         NaN
# 106949   5926 ALPINE SAN PABLO  94806-4107
# 51514           105  ORTEGA AV         NaN
# 173249                     NaN         NaN
# 53001    1412 12TH ST, OAKLAND       94607
# 95271        484 JERRYLEE ROAD         NaN
# 57011       1 DALEWOOD TERRACE         NaN
# 86221      840 CIVIC CENTER DR         NaN
# 88017     4628 BENNETT VIEW DR         NaN
# 173681        835 FIRST STREET         NaN
#
#                                          MTC_ADDRESS_FULL
# 175470              846  COTATI TR 9, SUNNYVALE, CA , USA
# 79363             562 FILBERT ST, SAN FRANCISCO, CA , USA
# 82315                    985 MORSE ST, SAN JOSE, CA , USA
# 99138           5517 PINNACLE VIEW WAY, ANTIOCH, CA , USA
# 46763         125 EDGEWOOD AVENUE, MARIN COUNTY, CA , USA
# 22070                   7040 KIRIGIN WY, GILROY, CA , USA
# 173584                13151 MCDOVE ST, SARATOGA, CA , USA
# 3907                 2291 RESERVE DR, BRENTWOOD, CA , USA
# 89127                234 NEWCOMB STREET, SONOMA, CA , USA
# 95171               443 POTTERS LANE, VACAVILLE, CA , USA
# 145542                 375 HANSFORD WAY, OAKLEY, CA , USA
# 106949  5926 ALPINE SAN PABLO, CONTRA COSTA COUNTY, CA...
# 51514             105  ORTEGA AV, MOUNTAIN VIEW, CA , USA
# 173249                                                NaN
# 53001       1412 12TH ST, OAKLAND, OAKLAND, CA 94607, USA
# 95271              484 JERRYLEE ROAD, VACAVILLE, CA , USA
# 57011                1 DALEWOOD TERRACE, ORINDA, CA , USA
# 86221          840 CIVIC CENTER DR, SANTA CLARA, CA , USA
# 88017          4628 BENNETT VIEW DR, SANTA ROSA, CA , USA
# 173681             835 FIRST STREET, SEBASTOPOL, CA , USA

# %%
#Create a geo locator
g = GoogleV3(api_key=google_api_key)

# %%
#Use a rate limiter
geocode = RateLimiter(g.geocode, min_delay_seconds=.25, error_wait_seconds=1)

# %%
#Create a location column with geolocator 
tqdm.pandas()
bound_box = [Point(38.864245, -123.632497), Point(36.893329, -121.208156)]
apr_bay_area['location'] = apr_bay_area['MTC_ADDRESS_FULL'].progress_apply(partial(geocode,
                                                                          components={"country": "USA"},
                                                                          bounds=bound_box),
                                                                          timeout=1000)
# Out:
# 100%|██████████| 30864/30864 [6:34:10<00:00,  1.30it/s]

# %%
apr_bay_area[apr_bay_area['location'].isnull()]
# Out:
#         JURS_NAME     CNTY_NAME    YEAR PRIOR_APN  \
# 612       ANTIOCH  CONTRA COSTA  2019.0       NaN
# 3291      BELMONT     SAN MATEO  2019.0  43072450
# 3294      BELMONT     SAN MATEO  2019.0  43222370
# 3304      BELMONT     SAN MATEO  2019.0  44260160
# 3310      BELMONT     SAN MATEO  2019.0  45201240
# ...           ...           ...     ...       ...
# 176006  SUNNYVALE   SANTA CLARA  2018.0       NaN
# 176008  SUNNYVALE   SANTA CLARA  2018.0       NaN
# 180491    WINDSOR        SONOMA  2018.0       NaN
# 180502    WINDSOR        SONOMA  2018.0       NaN
# 180503    WINDSOR        SONOMA  2018.0       NaN
#
#                                           APN                STREET_ADDRESS  \
# 612                                  52242033               2786 LILY COURT
# 3291                                 43072450          0 RALSTON RANCH ROAD
# 3294                                 43222370            0 LONGFELLOW DRIVE
# 3304                                 44260160                 0 RALSTON AVE
# 3310                                 45201240               0 TALBRYN DRIVE
# ...                                       ...                           ...
# 176006                               20934023        345 W MC KINLEY AV 526
# 176008                               20934023        345 W MC KINLEY AV 528
# 180491  066-060-004; 066-060-007; 066-060-021  711 AND 9500 OAK PARK STREET
# 180502                            163-320-022                1449 ACORN WAY
# 180503                            163-320-023                1443 ACORN WAY
#
#                     PROJECT_NAME JURS_TRACKING_ID  \
# 612                 DENOVA HOMES       B1907-0275
# 3291                         NaN      PA2018-0107
# 3294                         NaN      PA2018-0004
# 3304                         NaN      PA2018-0043
# 3310                         NaN      PA2018-0075
# ...                          ...              ...
# 176006               Town Center              NaN
# 176008               Town Center              NaN
# 180491  Windsor Veterans Village     17-18-UP-DRC
# 180502                  Portello         B17-0268
# 180503                  Portello         B17-0267
#
#                         UNIT_CAT_DESC  TENURE  ...  \
# 612       Single-Family Detached Unit   Owner  ...
# 3291      Single-Family Detached Unit   Owner  ...
# 3294      Single-Family Detached Unit   Owner  ...
# 3304      Single-Family Detached Unit   Owner  ...
# 3310      Single-Family Detached Unit   Owner  ...
# ...                               ...     ...  ...
# 176006  5 or More Units Per Structure  Renter  ...
# 176008  5 or More Units Per Structure  Renter  ...
# 180491  5 or More Units Per Structure  Renter  ...
# 180502    Single-Family Detached Unit   Owner  ...
# 180503    Single-Family Detached Unit   Owner  ...
#
#                              NO_FA_DR  TERM_AFF_DR  DEM_DES_UNITS  \
# 612                               NaN          NaN            NaN
# 3291                              NaN          NaN            NaN
# 3294                              NaN          NaN            NaN
# 3304                              NaN          NaN            NaN
# 3310    2nd Dwelling Unit Study, 2014          NaN            NaN
# ...                               ...          ...            ...
# 176006                            NaN          NaN            NaN
# 176008                            NaN          NaN            NaN
# 180491                            NaN           55            NaN
# 180502                            NaN          NaN            NaN
# 180503                            NaN          NaN            NaN
#
#        DEM_OR_DES_UNITS  DEM_DES_UNITS_OWN_RENT  \
# 612                 NaN                     NaN
# 3291                NaN                     NaN
# 3294                NaN                     NaN
# 3304                NaN                     NaN
# 3310                NaN                     NaN
# ...                 ...                     ...
# 176006              NaN                     NaN
# 176008              NaN                     NaN
# 180491              NaN                     NaN
# 180502              NaN                     NaN
# 180503              NaN                     NaN
#
#                                               NOTES  \
# 612                                             NaN
# 3291                                            NaN
# 3294                                            NaN
# 3304                                            NaN
# 3310                                            NaN
# ...                                             ...
# 176006                                          NaN
# 176008                                          NaN
# 180491  Award of $500,000 of in lieu housing funds.
# 180502                                          NaN
# 180503                                          NaN
#
#                   STREET_ADDRESS_FMT MTC_ZIP  \
# 612                  2786 LILY COURT     NaN
# 3291            0 RALSTON RANCH ROAD     NaN
# 3294              0 LONGFELLOW DRIVE     NaN
# 3304                   0 RALSTON AVE     NaN
# 3310                 0 TALBRYN DRIVE     NaN
# ...                              ...     ...
# 176006        345 W MC KINLEY AV 526     NaN
# 176008        345 W MC KINLEY AV 528     NaN
# 180491  711 AND 9500 OAK PARK STREET     NaN
# 180502                1449 ACORN WAY     NaN
# 180503                1443 ACORN WAY     NaN
#
#                                        MTC_ADDRESS_FULL  location
# 612                  2786 LILY COURT, ANTIOCH, CA , USA      None
# 3291            0 RALSTON RANCH ROAD, BELMONT, CA , USA      None
# 3294              0 LONGFELLOW DRIVE, BELMONT, CA , USA      None
# 3304                   0 RALSTON AVE, BELMONT, CA , USA      None
# 3310                 0 TALBRYN DRIVE, BELMONT, CA , USA      None
# ...                                                 ...       ...
# 176006      345 W MC KINLEY AV 526, SUNNYVALE, CA , USA      None
# 176008      345 W MC KINLEY AV 528, SUNNYVALE, CA , USA      None
# 180491  711 AND 9500 OAK PARK STREET, WINDSOR, CA , USA      None
# 180502                1449 ACORN WAY, WINDSOR, CA , USA      None
# 180503                1443 ACORN WAY, WINDSOR, CA , USA      None
#
# [527 rows x 52 columns]

# %%
apr_bay_area['location'].iloc[0]
# Out:
# Location(3040 Thompson Ave, Alameda, CA 94501, USA, (37.7614592, -122.2302331, 0.0))

# %%
apr_bay_area['location'].iloc[0].raw
# Out:
# {'address_components': [{'long_name': '3040',
#    'short_name': '3040',
#    'types': ['street_number']},
#   {'long_name': 'Thompson Avenue',
#    'short_name': 'Thompson Ave',
#    'types': ['route']},
#   {'long_name': 'Alameda',
#    'short_name': 'Alameda',
#    'types': ['locality', 'political']},
#   {'long_name': 'Alameda County',
#    'short_name': 'Alameda County',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': 'California',
#    'short_name': 'CA',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'United States',
#    'short_name': 'US',
#    'types': ['country', 'political']},
#   {'long_name': '94501', 'short_name': '94501', 'types': ['postal_code']},
#   {'long_name': '1754',
#    'short_name': '1754',
#    'types': ['postal_code_suffix']}],
#  'formatted_address': '3040 Thompson Ave, Alameda, CA 94501, USA',
#  'geometry': {'location': {'lat': 37.7614592, 'lng': -122.2302331},
#   'location_type': 'RANGE_INTERPOLATED',
#   'viewport': {'northeast': {'lat': 37.7628081802915,
#     'lng': -122.2288841197085},
#    'southwest': {'lat': 37.7601102197085, 'lng': -122.2315820802915}}},
#  'place_id': 'EikzMDQwIFRob21wc29uIEF2ZSwgQWxhbWVkYSwgQ0EgOTQ1MDEsIFVTQSIbEhkKFAoSCSHDdTiFho-AESzk10afWtDzEOAX',
#  'types': ['street_address']}

# %%
apr_bay_area['location'].iloc[0].raw['formatted_address']
# Out:
# '3040 Thompson Ave, Alameda, CA 94501, USA'

# %%
#Set geocode location type
apr_bay_area['MTC_GEOCODE_TYPE'] = apr_bay_area['location'].map(lambda loc: loc.raw['geometry']['location_type'] 
                                                                if loc else None)

# %%
#Set lattitude
apr_bay_area['MTC_LAT'] = (apr_bay_area['location']
                                        .map(lambda loc: loc.raw['geometry']['location']['lat']
                                             if loc else None))

# %%
#Set longitude 
apr_bay_area['MTC_LONG'] = (apr_bay_area['location']
                                        .map(lambda loc: loc.raw['geometry']['location']['lng']
                                             if loc else None))

# %%
#Set geocode address 
apr_bay_area['MTC_GEOCODE_ADDRESS'] = (apr_bay_area['location']
                                      .map(lambda loc: loc.raw['formatted_address']
                                          if loc else None))

# %%
os.listdir(os.path.join(work_dir,
                       '2019 Original APRs'))
# Out:
# ['Extracts',
#  'ORIGINAL_Table_A2_Report_with_Data_Dictionary.xlsx',
#  'ORIGINAL_Table_A_2018_2019.xlsx',
#  'ORIGINAL_Table_D_Report.xlsx',
#  'Table_A2_Report_Address_Lat_Long.xlsx',
#  'Table_A2_Report_Lat_Long_Google.csv']

# %%
# # Write temporary output to csv
# apr_bay_area.to_csv(os.path.join(work_dir,
#                        '2019 Original APRs',
#                                 'Table_A2_Report_Lat_Long_Google.csv'),
#                    index=False)

# %%
#Read temporary output csv back into notebook
apr_bay_area = pd.read_csv(os.path.join(work_dir,
                                        '2019 Original APRs',
                                        'Table_A2_Report_Lat_Long_Google.csv'))

# %%
apr_bay_area.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30864 entries, 0 to 30863
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   JURS_NAME                    30864 non-null  object
#  1   CNTY_NAME                    30864 non-null  object
#  2   YEAR                         30864 non-null  int64
#  3   PRIOR_APN                    2983 non-null   object
#  4   APN                          30680 non-null  object
#  5   STREET_ADDRESS               30686 non-null  object
#  6   PROJECT_NAME                 14339 non-null  object
#  7   JURS_TRACKING_ID             23670 non-null  object
#  8   UNIT_CAT_DESC                30864 non-null  object
#  9   TENURE                       30864 non-null  object
#  10  VLOW_INCOME_DR               30864 non-null  int64
#  11  VLOW_INCOME_NDR              30864 non-null  int64
#  12  LOW_INCOME_DR                30864 non-null  int64
#  13  LOW_INCOME_NDR               30864 non-null  int64
#  14  MOD_INCOME_DR                30864 non-null  int64
#  15  MOD_INCOME_NDR               30864 non-null  int64
#  16  ABOVE_MOD_INCOME             30864 non-null  int64
#  17  ENT_APPROVE_DT               5453 non-null   object
#  18  NO_ENTITLEMENTS              30864 non-null  int64
#  19  BP_VLOW_INCOME_DR            30864 non-null  int64
#  20  BP_VLOW_INCOME_NDR           30864 non-null  int64
#  21  BP_LOW_INCOME_DR             30864 non-null  int64
#  22  BP_LOW_INCOME_NDR            30864 non-null  int64
#  23  BP_MOD_INCOME_DR             30864 non-null  int64
#  24  BP_MOD_INCOME_NDR            30864 non-null  int64
#  25  BP_ABOVE_MOD_INCOME          30864 non-null  int64
#  26  BP_ISSUE_DT                  17812 non-null  object
#  27  NO_BILDING_PERMITS           30864 non-null  int64
#  28  CO_VLOW_INCOME_DR            30864 non-null  int64
#  29  CO_VLOW_INCOME_NDR           30864 non-null  int64
#  30  CO_LOW_INCOME_DR             30864 non-null  int64
#  31  CO_LOW_INCOME_NDR            30864 non-null  int64
#  32  CO_MOD_INCOME_DR             30864 non-null  int64
#  33  CO_MOD_INCOME_NDR            30864 non-null  int64
#  34  CO_ABOVE_MOD_INCOME          30864 non-null  int64
#  35  CO_ISSUE_DT                  13269 non-null  object
#  36  NO_OTHER_FORMS_OF_READINESS  30864 non-null  int64
#  37  EXTR_LOW_INCOME_UNITS        2053 non-null   float64
#  38  APPROVE_SB35                 30864 non-null  object
#  39  INFILL_UNITS                 15675 non-null  object
#  40  FIN_ASSIST_NAME              474 non-null    object
#  41  DR_TYPE                      1110 non-null   object
#  42  NO_FA_DR                     5121 non-null   object
#  43  TERM_AFF_DR                  757 non-null    float64
#  44  DEM_DES_UNITS                1413 non-null   float64
#  45  DEM_OR_DES_UNITS             1171 non-null   object
#  46  DEM_DES_UNITS_OWN_RENT       1142 non-null   object
#  47  NOTES                        4474 non-null   object
#  48  STREET_ADDRESS_FMT           30686 non-null  object
#  49  MTC_ZIP                      3383 non-null   object
#  50  MTC_ADDRESS_FULL             30686 non-null  object
#  51  location                     30337 non-null  object
#  52  MTC_GEOCODE_TYPE             30337 non-null  object
#  53  MTC_LAT                      30337 non-null  float64
#  54  MTC_LONG                     30337 non-null  float64
#  55  MTC_GEOCODE_ADDRESS          30337 non-null  object
# dtypes: float64(5), int64(25), object(26)
# memory usage: 13.2+ MB

# %%
#Create geodataframe from lat long coords
apr_bay_area_geo = gp.GeoDataFrame(apr_bay_area,
                                  geometry=gp.points_from_xy(apr_bay_area['MTC_LONG'],apr_bay_area['MTC_LAT']),
                                  crs="EPSG:4326")

# %%
apr_bay_area_geo.head(5)
# Out:
#   JURS_NAME CNTY_NAME  YEAR PRIOR_APN        APN     STREET_ADDRESS  \
# 0   ALAMEDA   ALAMEDA  2019       NaN  69-106-19  3040 THOMPSON AVE
# 1   ALAMEDA   ALAMEDA  2019       NaN  69-130-11     2916 MARINA DR
# 2   ALAMEDA   ALAMEDA  2019       NaN    69-64-1      1206 COURT ST
# 3   ALAMEDA   ALAMEDA  2019       NaN    69-77-1   1322 FOUNTAIN ST
# 4   ALAMEDA   ALAMEDA  2019       NaN    69-99-6      1515 COURT ST
#
#   PROJECT_NAME JURS_TRACKING_ID            UNIT_CAT_DESC  TENURE  ...  NOTES  \
# 0          NaN        CB19-0152  Accessory Dwelling Unit  Renter  ...    NaN
# 1          NaN        CB19-0317  Accessory Dwelling Unit  Renter  ...    NaN
# 2          NaN        CB19-0426  Accessory Dwelling Unit  Renter  ...    NaN
# 3          NaN        CB19-0236  Accessory Dwelling Unit  Renter  ...    NaN
# 4          NaN        CB18-1068  Accessory Dwelling Unit  Renter  ...    NaN
#
#    STREET_ADDRESS_FMT  MTC_ZIP                      MTC_ADDRESS_FULL  \
# 0   3040 THOMPSON AVE      NaN  3040 THOMPSON AVE, ALAMEDA, CA , USA
# 1      2916 MARINA DR      NaN     2916 MARINA DR, ALAMEDA, CA , USA
# 2       1206 COURT ST      NaN      1206 COURT ST, ALAMEDA, CA , USA
# 3    1322 FOUNTAIN ST      NaN   1322 FOUNTAIN ST, ALAMEDA, CA , USA
# 4       1515 COURT ST      NaN      1515 COURT ST, ALAMEDA, CA , USA
#
#                                     location    MTC_GEOCODE_TYPE    MTC_LAT  \
# 0  3040 Thompson Ave, Alameda, CA 94501, USA  RANGE_INTERPOLATED  37.761459
# 1     2916 Marina Dr, Alameda, CA 94501, USA  RANGE_INTERPOLATED  37.766979
# 2      1206 Court St, Alameda, CA 94501, USA  RANGE_INTERPOLATED  37.756314
# 3   1322 Fountain St, Alameda, CA 94501, USA  RANGE_INTERPOLATED  37.757186
# 4      1515 Court St, Alameda, CA 94501, USA  RANGE_INTERPOLATED  37.760636
#
#      MTC_LONG                        MTC_GEOCODE_ADDRESS  \
# 0 -122.230233  3040 Thompson Ave, Alameda, CA 94501, USA
# 1 -122.228978     2916 Marina Dr, Alameda, CA 94501, USA
# 2 -122.236484      1206 Court St, Alameda, CA 94501, USA
# 3 -122.234114   1322 Fountain St, Alameda, CA 94501, USA
# 4 -122.232302      1515 Court St, Alameda, CA 94501, USA
#
#                       geometry
# 0  POINT (-122.23023 37.76146)
# 1  POINT (-122.22898 37.76698)
# 2  POINT (-122.23648 37.75631)
# 3  POINT (-122.23411 37.75719)
# 4  POINT (-122.23230 37.76064)
#
# [5 rows x 57 columns]

# %%
sf_permits[sf_permits['MTC_GEOCODE_ADDRESS'].isnull()].size
# Out:
# 72

# %%
sf_permits = (apr_bay_area_geo[['MTC_GEOCODE_TYPE','MTC_GEOCODE_ADDRESS','geometry']]
              [(apr_bay_area_geo['JURS_NAME'] == 'SAN FRANCISCO') & 
               (apr_bay_area_geo['MTC_GEOCODE_ADDRESS'].notnull())])

# %%
sf_permits.head(5)
# Out:
#       MTC_GEOCODE_TYPE                               MTC_GEOCODE_ADDRESS  \
# 10458          ROOFTOP   1327 Columbus Ave, San Francisco, CA 94133, USA
# 10459          ROOFTOP  2741 Hyde St #2743, San Francisco, CA 94109, USA
# 10460          ROOFTOP   1255 Columbus Ave, San Francisco, CA 94133, USA
# 10461          ROOFTOP    15 Vandewater St, San Francisco, CA 94133, USA
# 10462          ROOFTOP       28 Houston St, San Francisco, CA 94133, USA
#
#                           geometry
# 10458  POINT (-122.41933 37.80638)
# 10459  POINT (-122.42075 37.80627)
# 10460  POINT (-122.41817 37.80555)
# 10461  POINT (-122.41241 37.80525)
# 10462  POINT (-122.41610 37.80400)

# %%
#Plot points 
map = folium.Map(location=(37.830787, -122.362624),
                zoom_start=11)

permits = folium.features.GeoJson(sf_permits.to_json())

map.add_child(permits)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
apr_bay_area_geo['MTC_GEOCODE_TYPE'].unique()
# Out:
# array(['RANGE_INTERPOLATED', 'ROOFTOP', 'GEOMETRIC_CENTER', 'APPROXIMATE',
#        nan], dtype=object)

# %%
geocode_type_summary = ((apr_bay_area_geo[['MTC_GEOCODE_TYPE']].fillna('NO_GEOCODE_TYPE'))
                        .groupby('MTC_GEOCODE_TYPE')
                        .agg({'MTC_GEOCODE_TYPE':'count'})
                        .rename(columns={'MTC_GEOCODE_TYPE':'GEOCODE_COUNT'})
                        .reset_index())
geocode_type_summary
# Out:
#      MTC_GEOCODE_TYPE  GEOCODE_COUNT
# 0         APPROXIMATE            555
# 1    GEOMETRIC_CENTER           1463
# 2     NO_GEOCODE_TYPE            527
# 3  RANGE_INTERPOLATED           4933
# 4             ROOFTOP          23386

# %%
geocode_type_summary['GEOCODE_PERCENTAGE'] = geocode_type_summary[['GEOCODE_COUNT']].apply(lambda x: (x/x.sum()*100))
geocode_type_summary
# Out:
#      MTC_GEOCODE_TYPE  GEOCODE_COUNT  GEOCODE_PERCENTAGE
# 0         APPROXIMATE            555            1.798212
# 1    GEOMETRIC_CENTER           1463            4.740150
# 2     NO_GEOCODE_TYPE            527            1.707491
# 3  RANGE_INTERPOLATED           4933           15.983022
# 4             ROOFTOP          23386           75.771125

# %% [markdown]
# **[Back to Top](#top)**
#
# **[Back to Section Top](#geocode)**

# %% [markdown]
# ## Create income category summary columns <a name='income_categories'></a>
#
# **[Skip to next step](#)**

# %%
apr_bay_area_geo.columns
# Out:
# Index(['JURS_NAME', 'CNTY_NAME', 'YEAR', 'PRIOR_APN', 'APN', 'STREET_ADDRESS',
#        'PROJECT_NAME', 'JURS_TRACKING_ID', 'UNIT_CAT_DESC', 'TENURE',
#        'VLOW_INCOME_DR', 'VLOW_INCOME_NDR', 'LOW_INCOME_DR', 'LOW_INCOME_NDR',
#        'MOD_INCOME_DR', 'MOD_INCOME_NDR', 'ABOVE_MOD_INCOME', 'ENT_APPROVE_DT',
#        'NO_ENTITLEMENTS', 'BP_VLOW_INCOME_DR', 'BP_VLOW_INCOME_NDR',
#        'BP_LOW_INCOME_DR', 'BP_LOW_INCOME_NDR', 'BP_MOD_INCOME_DR',
#        'BP_MOD_INCOME_NDR', 'BP_ABOVE_MOD_INCOME', 'BP_ISSUE_DT',
#        'NO_BILDING_PERMITS', 'CO_VLOW_INCOME_DR', 'CO_VLOW_INCOME_NDR',
#        'CO_LOW_INCOME_DR', 'CO_LOW_INCOME_NDR', 'CO_MOD_INCOME_DR',
#        'CO_MOD_INCOME_NDR', 'CO_ABOVE_MOD_INCOME', 'CO_ISSUE_DT',
#        'NO_OTHER_FORMS_OF_READINESS', 'EXTR_LOW_INCOME_UNITS', 'APPROVE_SB35',
#        'INFILL_UNITS', 'FIN_ASSIST_NAME', 'DR_TYPE', 'NO_FA_DR', 'TERM_AFF_DR',
#        'DEM_DES_UNITS', 'DEM_OR_DES_UNITS', 'DEM_DES_UNITS_OWN_RENT', 'NOTES',
#        'STREET_ADDRESS_FMT', 'MTC_ZIP', 'MTC_ADDRESS_FULL', 'location',
#        'MTC_GEOCODE_TYPE', 'MTC_LAT', 'MTC_LONG', 'MTC_GEOCODE_ADDRESS',
#        'geometry'],
#       dtype='object')

# %%
#Create count columns for sum of units by income category
apr_bay_area_geo['MTC_VLOW_TOT'] = apr_bay_area_geo['VLOW_INCOME_DR'] + apr_bay_area_geo['VLOW_INCOME_NDR']
apr_bay_area_geo['MTC_MOD_TOT'] = apr_bay_area_geo['LOW_INCOME_DR'] + apr_bay_area_geo['LOW_INCOME_NDR']
apr_bay_area_geo['MTC_LOW_TOT'] = apr_bay_area_geo['MOD_INCOME_DR'] + apr_bay_area_geo['MOD_INCOME_NDR']

# %%
IF CO_VLOW_INCOME_NDR_CON_ENT_PERM > 0, 
THEN CO_VLOW_INCOME_NDR_CON_ENT_PERM 
ELSE IF BP_VLOW_INCOME_NDR_CON_ENT_PERM 
THEN BP_VLOW_INCOME_NDR_CON_ENT_PERM
ELSE IF VLOW_INCOME_NDR_CON_ENT_PERMITS > 0 
THEN VLOW_INCOME_NDR_CON_ENT_PERMITS

# %%
#Create function to calculate income category permit count

def sum_permits_by_income(row,co_col,bp_col,entitle_col):
    if (row[co_col] > 0):
        return row[co_col]
    elif (row[bp_col] > 0):
        return row[bp_col]
    elif (row[entitle_col] > 0):
        return row[entitle_col]

# %%
apr_bay_area_geo['MTC_VLOW_INCOME_NDR'] = apr_bay_area_geo.apply(lambda row: 
                                                                 sum_permits_by_income(row,
                                                                                    'CO_VLOW_INCOME_NDR',
                                                                                     'BP_VLOW_INCOME_NDR',
                                                                                     'VLOW_INCOME_NDR'
                                                                                    ),
                                                                 axis=1)

# %%
apr_bay_area_geo[apr_bay_area_geo['MTC_VLOW_INCOME_NDR'] > 2]
# Out:
#               JURS_NAME    CNTY_NAME  YEAR PRIOR_APN            APN  \
# 8883          PALO ALTO  SANTA CLARA  2019       NaN     132-35-045
# 12948  SAN MATEO COUNTY    SAN MATEO  2019  Entitled       54113140
# 17316          BERKELEY      ALAMEDA  2018       NaN  056 196001404
# 27420  SAN MATEO COUNTY    SAN MATEO  2018       NaN       60265050
# 28611        SANTA ROSA       SONOMA  2018       NaN      173030029
#
#                                      STREET_ADDRESS          PROJECT_NAME  \
# 8883                            3705 EL CAMINO REAL                   NaN
# 12948  2700 MIDDLEFIELD ROAD, REDWOOD CITY CA 94063  Middlefield Junction
# 17316                            2001 FOURTH STREET                   NaN
# 27420                 105 5TH AVE, REDWOOD CITY, CA         Waverly Place
# 28611                                           NaN               RUSSELL
#
#       JURS_TRACKING_ID                  UNIT_CAT_DESC  TENURE  ...  \
# 8883       18PLN-00136  5 or More Units Per Structure  Renter  ...
# 12948    PLN2019-00320  5 or More Units Per Structure  Renter  ...
# 17316              NaN  5 or More Units Per Structure  Renter  ...
# 27420    BLD2015-01761  5 or More Units Per Structure  Renter  ...
# 28611              AVE    Single-Family Detached Unit  Renter  ...
#
#                                                location  MTC_GEOCODE_TYPE  \
# 8883      3705 El Camino Real, Palo Alto, CA 94306, USA           ROOFTOP
# 12948  2700 Middlefield Rd, Redwood City, CA 94063, USA           ROOFTOP
# 17316           2001 Fourth St, Berkeley, CA 94710, USA           ROOFTOP
# 27420        105 Fifth Ave, Redwood City, CA 94063, USA           ROOFTOP
# 28611                                               NaN               NaN
#
#          MTC_LAT    MTC_LONG  \
# 8883   37.418378 -122.132401
# 12948  37.475026 -122.212471
# 17316  37.867366 -122.299280
# 27420  37.469259 -122.207616
# 28611        NaN         NaN
#
#                                     MTC_GEOCODE_ADDRESS  \
# 8883      3705 El Camino Real, Palo Alto, CA 94306, USA
# 12948  2700 Middlefield Rd, Redwood City, CA 94063, USA
# 17316           2001 Fourth St, Berkeley, CA 94710, USA
# 27420        105 Fifth Ave, Redwood City, CA 94063, USA
# 28611                                               NaN
#
#                           geometry  MTC_VLOW_TOT MTC_MOD_TOT  MTC_LOW_TOT  \
# 8883   POINT (-122.13240 37.41838)            58           5            0
# 12948  POINT (-122.21247 37.47503)           119          59            0
# 17316  POINT (-122.29928 37.86737)             0           0            0
# 27420  POINT (-122.20762 37.46926)             0           0            0
# 28611              POINT (nan nan)            14           0            0
#
#        MTC_VLOW_INCOME_NDR
# 8883                  58.0
# 12948                 59.0
# 17316                 12.0
# 27420                  7.0
# 28611                 14.0
#
# [5 rows x 61 columns]

# %% [markdown]
# **[Back to Top](#top)**
#
# **[Back to Section Top](#income_categories)**
