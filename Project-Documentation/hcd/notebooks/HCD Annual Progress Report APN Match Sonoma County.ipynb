# %%
import sys
import getpass
import re
from functools import partial
from tqdm import tqdm
import uuid

user = getpass.getuser()
sys.dont_write_bytecode = True

sys.path.insert(0, '/Users/{}/Box/DataViz Projects/Utility Code'.format(user))

from utils_io import *  # initial imports
reload_module('utils_io')  # reload after update to utils_io.py
from utils_io import *  # reload reflects updates

#geo imports
import geopandas as gp
import folium
from geopandas.tools import geocode
from geopy.geocoders import GoogleV3
from geopy.extra.rate_limiter import RateLimiter
from geopy import Point

# %% [markdown]
# ## Match un-geocoded projects by APN
#
# -[ParcelAtlas v24 (BASIS)](https://data.bayareametro.gov/Cadastral/ParcelAtlas-v24-BASIS-/8hp3-7hq6)

# %%
parcels_id = '8hp3-7hq6'

# %%
#Pull Sonoma County Parcels from Socrata
query_args = {'where': "county = 'Sonoma'"}
parcels_sonoma = pull_df_from_socrata(parcels_id,query_args=query_args)
# Out:
# pulling data in 9 chunks of 22000 rows each
# pulling chunk 0
# pulling chunk 1
# pulling chunk 2
# pulling chunk 3
# pulling chunk 4
# pulling chunk 5
# pulling chunk 6
# pulling chunk 7
# pulling chunk 8
# took 52.8932 seconds

# %%
#Pull un-geocoded sonoma projects from Socrata
apr_id = 'briv-ikjp'
query_args = {'where': "cnty_name = 'SONOMA'"}

# %%
sonoma_projects = pull_df_from_socrata(apr_id,query_args=query_args)
# Out:
# pulling data in 1 chunks of 3787 rows each
# pulling chunk 0
# took 3.4189 seconds

# %%
sonoma_projects[['mtc_id','apn','mtc_address_full','street_address','mtc_wkt']].sample(n=20)
# Out:
#                                     mtc_id          apn  \
# 85    d2b0ba0a-4b17-41cd-bacd-3792a5aa2819  002-152-008
# 2435  56a4c4fc-b048-4aab-a449-477a60491765          TBD
# 1443  1efb75f5-547e-4d74-8a48-cd4f61b177b9  029-240-007
# 2748  648bc151-355a-449f-a06e-7641bfd97f5d  159-590-071
# 2954  74f1fd25-6f82-462f-9015-76ab2b1fc594    157020009
# 3400  261e0404-4ef1-4683-b3e9-b2eda48be639  020-050-017
# 2579  79d42bcf-4d67-4eaf-8a31-dcf374c0e4af  159-560-023
# 1315  8f7552c0-d25d-42e0-a4d2-e0b435bfb7ef  127-211-009
# 1073  3f9d9fa5-304d-4cd9-8bcf-351d5ebe7b1d    125031022
# 3390  34b2dcab-ceec-4650-b5e2-5436f709bcf6  128-131-051
# 3676  5108a768-35cc-4da2-8f79-c920960710be  127-061-029
# 2785  140ed237-35ce-45db-90ea-d9ef778755ea  159-610-001
# 1438  3795572e-f27e-428f-aa10-fc2c5ee2ad27  029-222-006
# 102   8e099975-544c-42d8-88ef-0a90c533cdae  088-280-079
# 675   9c004a39-1b64-4f73-884e-f419a8281219  159-650-078
# 3253  f91ca98b-8b9d-4dd7-a9f6-1f01a4d15422     35850027
# 410   b0f3ffba-22fe-405f-af56-e56b5d3215ce  159-560-033
# 2360  d1d7155a-cd73-4936-9861-2834ea6f2024  089-011-013
# 1610  26f2ee2c-27c4-45b5-af7c-87f26bd25ea4  050-290-006
# 2489  01be4e85-d400-412e-9e53-0131f2712188          NaN
#
#                                        mtc_address_full  \
# 85                   402PIPER ST., HEALDSBURG, CA , USA
# 2435                          TBD, HEALDSBURG, CA , USA
# 1443  3655 ROLLING OAKS RD, SANTA ROSA, SONOMA COUNT...
# 2748        5315 KELLIANN PLACE, ROHNERT PARK, CA , USA
# 2954                                                NaN
# 3400     1709 SPRING HILL ROAD, SONOMA COUNTY, CA , USA
# 2579          5137 KOLTON PLACE, ROHNERT PARK, CA , USA
# 1315  840 WEST NAPA STREET UNITS E & F BLDG. 4, SONO...
# 1073              1619 SENDERO LN, SANTA ROSA, CA , USA
# 3390               164 NEWCOMB STREET, SONOMA, CA , USA
# 3676  2191 HATPAT LN, SONOMA, SONOMA COUNTY, CA 9547...
# 2785        1608 WILDFLOWER WAY, ROHNERT PARK, CA , USA
# 1438  3541 OAKHAVEN CT, SANTA ROSA, SONOMA COUNTY, C...
# 102                107 KENNEDY LN, HEALDSBURG, CA , USA
# 675           5933 KEEGAN PLACE, ROHNERT PARK, CA , USA
# 3253              948 BRUNELLO DR, SANTA ROSA, CA , USA
# 410             1814 KYLE PLACE, ROHNERT PARK, CA , USA
# 2360              1553 CHABLIS RD, HEALDSBURG, CA , USA
# 1610  122 TREEHAVEN CT, KENWOOD, SONOMA COUNTY, CA 9...
# 2489           816 WELLINGTON PLACE, PETALUMA, CA , USA
#
#                                  street_address  \
# 85                                 402PIPER ST.
# 2435                                        TBD
# 1443  3655 ROLLING OAKS RD, SANTA ROSA CA 95404
# 2748                        5315 KELLIANN PLACE
# 2954                                        NaN
# 3400                      1709 SPRING HILL ROAD
# 2579                          5137 KOLTON PLACE
# 1315   840 WEST NAPA STREET UNITS E & F BLDG. 4
# 1073                            1619 SENDERO LN
# 3390                         164 NEWCOMB STREET
# 3676            2191 HATPAT LN, SONOMA CA 95476
# 2785                        1608 WILDFLOWER WAY
# 1438      3541 OAKHAVEN CT, SANTA ROSA CA 95404
# 102                              107 KENNEDY LN
# 675                           5933 KEEGAN PLACE
# 3253                            948 BRUNELLO DR
# 410                             1814 KYLE PLACE
# 2360                            1553 CHABLIS RD
# 1610         122 TREEHAVEN CT, KENWOOD CA 95452
# 2489                       816 WELLINGTON PLACE
#
#                                                 mtc_wkt
# 85    {'type': 'Point', 'coordinates': [-122.8656688...
# 2435  {'type': 'Point', 'coordinates': [-122.8691609...
# 1443  {'type': 'Point', 'coordinates': [-122.676313,...
# 2748  {'type': 'Point', 'coordinates': [-122.676886,...
# 2954                                                NaN
# 3400  {'type': 'Point', 'coordinates': [-122.6875376...
# 2579  {'type': 'Point', 'coordinates': [-122.68008, ...
# 1315  {'type': 'Point', 'coordinates': [-122.4739458...
# 1073  {'type': 'Point', 'coordinates': [-122.7395491...
# 3390  {'type': 'Point', 'coordinates': [-122.4619364...
# 3676  {'type': 'Point', 'coordinates': [-122.4085095...
# 2785  {'type': 'Point', 'coordinates': [-122.675494,...
# 1438  {'type': 'Point', 'coordinates': [-122.7022099...
# 102   {'type': 'Point', 'coordinates': [-122.8606145...
# 675   {'type': 'Point', 'coordinates': [-122.668827,...
# 3253  {'type': 'Point', 'coordinates': [-122.758534,...
# 410   {'type': 'Point', 'coordinates': [-122.6794501...
# 2360  {'type': 'Point', 'coordinates': [-122.883806,...
# 1610  {'type': 'Point', 'coordinates': [-122.5549222...
# 2489  {'type': 'Point', 'coordinates': [-122.65235, ...

# %% [markdown]
# ## Format APNs to match Sonoma County Pattern

# %%
#Subset apns that match the county pattern
regex_ctny_pattern = r'\d{3}-\d{3}-\d{3}'
sonoma_apn_reg = sonoma_projects[['apn']][sonoma_projects['apn'].str.contains(regex_ctny_pattern,na=False)]

# %%
#Create a column with formatted apn, setting it to the first correctly mattched pattern 
#if multiple apns listed in column
regex_ctny_extract_pattern = r'(^\d{3}-\d{3}-\d{3})'
sonoma_apn_reg['apn_fmt'] = sonoma_apn_reg['apn'].str.extract(regex_ctny_extract_pattern)

# %%
sonoma_apn_reg.shape
# Out:
# (2389, 2)

# %%
#update the main dataframe with updated values
sonoma_projects['mtc_apn_fmt'].update(sonoma_apn_reg['apn_fmt'])

# %%
sonoma_projects[['mtc_id','apn','mtc_apn_fmt']][sonoma_projects['mtc_apn_fmt'].notnull()].sample(n=15)
# Out:
#                                     mtc_id          apn  mtc_apn_fmt
# 530   51e9a071-9737-440a-9cd5-8477354afcad  159-620-037  159-620-037
# 2370  0e1f4e52-9e3b-44e1-9a1f-f0cbbc409ed4  002-091-015  002-091-015
# 2134  1a95783d-f9f3-4b4c-b050-face346c98c5  082-143-078  082-143-078
# 2752  327d05a7-a4b9-497f-8576-0e7c7829716c  159-590-084  159-590-084
# 1853  b24acec8-8c89-464a-add8-c3692b4dea9f  058-300-035  058-300-035
# 2392  9cb7679c-7fad-41ea-a951-b38dc9e39a09  091-330-001  091-330-001
# 2617  df698a2a-ef1b-47f2-9a80-0f9c4e3201bb  159-570-010  159-570-010
# 1706  5d1ff2c1-0ac7-4586-b651-a4745ef41abe  055-193-006  055-193-006
# 1734  e0fbc78a-1a2e-41a4-9cb3-228db7a7116d  058-031-012  058-031-012
# 2857  dd3d73f5-176b-4628-b1b0-0750fd11b56f  159-610-084  159-610-084
# 2642  6ade76d0-438f-4686-af77-165fdd3861ac  159-570-038  159-570-038
# 2117  b5460a43-2aa0-47d7-8f06-98bc6c3f5126  079-070-012  079-070-012
# 2781  d37ca002-cf72-4677-9c71-c3e80674b813  159-600-029  159-600-029
# 3771  66b939dd-6793-4326-b87c-01e0e7f2c9b8  163-320-036  163-320-036
# 3575  6dae54a9-b5c0-4c49-ad8b-3ce4910ba8ce  072-021-004  072-021-004

# %%
#Select apns of length 8
#These apns need to be pre-pended with a leading 0 and seperated by dashes every 3 digits
sonoma_apn_eight_dig = sonoma_projects[['apn']].loc[sonoma_projects['apn'].str.len() == 8]

# %%
sonoma_apn_eight_dig.shape
# Out:
# (547, 1)

# %%
sonoma_apn_eight_dig['apn_fmt'] = '0' + sonoma_apn_eight_dig['apn']

# %%
sonoma_apn_eight_dig['apn_fmt'] = (sonoma_apn_eight_dig['apn_fmt'].str[0:3] + 
                                 '-' +
                                 sonoma_apn_eight_dig['apn_fmt'].str[3:6] +
                                 '-' +
                                 sonoma_apn_eight_dig['apn_fmt'].str[6:])

# %%
#Update original dataframe apn_fmt column with correctly formatted apn
sonoma_projects['mtc_apn_fmt'].update(sonoma_apn_eight_dig['apn_fmt'])

# %%
sonoma_projects[['mtc_id','apn','mtc_apn_fmt']][sonoma_projects['apn'].str.len() == 8].sample(n=15)
# Out:
#                                     mtc_id       apn  mtc_apn_fmt
# 3176  be9fac4d-701d-4242-8850-19d95cff7ab2  34030013  034-030-013
# 765   6f3a53c3-5506-4ae4-b54a-20a0206fae88  10311028  010-311-028
# 807   e8a250d6-fb0f-4e80-9c0d-da657d9f943f  31180017  031-180-017
# 1166  73babc64-74a0-4505-a4cc-0bee96571458  15533046  015-533-046
# 3319  c14639fd-9439-4e8c-9e09-0bacbf2a12cb  38192025  038-192-025
# 812   209ac3dc-5ca5-4aef-989b-9b42531b6529  34030013  034-030-013
# 3179  e3c89d47-6527-4dd8-9d00-d05d396f55c4  34030013  034-030-013
# 963   45d34354-2b4a-43e7-8555-99e7800f80f7  59010009  059-010-009
# 801   34258d9c-214d-4dd2-92da-75f9f819792f  14670015  014-670-015
# 1234  e9e2e479-5d73-401c-8faf-5da53981abdb  32010044  032-010-044
# 201   3ad101ee-0960-44ea-adc3-57124b66298e  37240021  037-240-021
# 798   651c882f-26d6-41f4-9c02-58b566727636  14652028  014-652-028
# 3180  bf22dc8c-0db3-4228-80f1-025559766736  34030013  034-030-013
# 910   e3ea15fb-5817-4b67-8849-739e04defd28  36860008  036-860-008
# 825   3c508bb9-ba75-4821-bdea-f0c92cba6504  34350016  034-350-016

# %%
#Extract 9 digit apns
regex_nine = r'^\d{9}'
sonoma_apn_nine_dig = sonoma_projects[['mtc_id','apn','mtc_apn_fmt']][sonoma_projects['apn']
                                                                      .str.contains(regex_nine,na=False)]

# %%
sonoma_apn_nine_dig.shape
# Out:
# (639, 3)

# %%
#Extract 9 digit apns into apn fmt column but only the first occurance if multiple apns
regex_nine_extract = r'(^\d{9})'
sonoma_apn_nine_dig['apn_fmt'] = sonoma_apn_nine_dig['apn'].str.extract(regex_nine_extract)

# %%
sonoma_apn_nine_dig['apn_fmt'] = (sonoma_apn_nine_dig['apn_fmt'].str[0:3] + 
                                 '-' +
                                 sonoma_apn_nine_dig['apn_fmt'].str[3:6] +
                                 '-' +
                                 sonoma_apn_nine_dig['apn_fmt'].str[6:])

# %%
sonoma_apn_nine_dig
# Out:
#                                     mtc_id        apn  mtc_apn_fmt  \
# 0     b3a34e42-6e61-4455-be49-7cf127087133  153590023  153-590-023
# 1     dfa4745a-2419-4663-a092-99fbefcba732  153590024  153-590-024
# 2     bc0537c3-54ea-4b2e-86db-be232c6498c7  153590025  153-590-025
# 3     370a4f7e-9e66-4881-bbd0-a4f944f2fcc2  153590026  153-590-026
# 4     b78008b8-b43a-475e-b445-de8df4b981c5  153600001  153-600-001
# ...                                    ...        ...          ...
# 3163  224e13cc-91e9-44f5-be0b-e8a8891c30bf  182520079  182-520-079
# 3164  69c0f2d5-9f10-4623-85a0-87adcfa792b3  182520079  182-520-079
# 3165  867af865-b051-495a-b94e-dd54e8e528f1  183400046  183-400-046
# 3166  89728b5c-ac37-444f-9b02-3210b2c3df1c  183440021  183-440-021
# 3786  745a0623-6a0e-4cfa-bbf6-a2e4c696c2b3  125071014  125-071-014
#
#           apn_fmt
# 0     153-590-023
# 1     153-590-024
# 2     153-590-025
# 3     153-590-026
# 4     153-600-001
# ...           ...
# 3163  182-520-079
# 3164  182-520-079
# 3165  183-400-046
# 3166  183-440-021
# 3786  125-071-014
#
# [639 rows x 4 columns]

# %%
#Update original dataframe apn_fmt column with correctly formatted apn
sonoma_projects['mtc_apn_fmt'].update(sonoma_apn_nine_dig['apn_fmt'])

# %%
sonoma_projects[['mtc_id','apn','mtc_apn_fmt']][sonoma_projects['apn'].str.len() == 9].sample(n=15)
# Out:
#                                     mtc_id        apn  mtc_apn_fmt
# 1147  32846645-d8de-4018-b98c-ddeaf09381a7  125252004  125-252-004
# 3092  c1cd3513-8055-4bc6-8c97-70fc46795afe  157020009  157-020-009
# 2991  dbc17b4e-7755-4dfe-878b-eaa32ab44e30  125071014  125-071-014
# 1131  fd20ed78-99ac-41e0-a340-a174e01563d7  125071014  125-071-014
# 1134  f8145bd4-51a8-43aa-b299-32e927738df7  125071014  125-071-014
# 1126  1ab61e57-8cef-4306-9a90-3248a0656fe9  125071014  125-071-014
# 17    963da6d9-2b3b-4632-8a3e-0977093ea327  153610003  153-610-003
# 1058  2371ba93-fefd-4a93-aaee-8ec53d5b4d7b  125031022  125-031-022
# 307   dfae5aea-4229-4e5e-bf46-609be3befd77  137520014  137-520-014
# 1016  7cce66b4-4adc-4beb-a44c-de8cd3db69ad  125031022  125-031-022
# 1117  8d2edbb8-02a4-4cbe-b49f-f90afc8faed9  125071014  125-071-014
# 3120  d3cb7275-6fb3-412f-835c-b1e2bcc69a3c  157020009  157-020-009
# 1098  a31c6bcd-d2a3-44c3-84f3-2fa9c8e6af48  125071014  125-071-014
# 1205  c522d238-5ee4-4740-9acc-5af6fb4dd2dd  173790010  173-790-010
# 311   74fa989f-31c3-4256-b240-56d793c2750f  137520017  137-520-017

# %%
sonoma_projects[['mtc_id','apn','mtc_apn_fmt']][sonoma_projects['mtc_apn_fmt'].isnull()]
# Out:
#                                     mtc_id            apn mtc_apn_fmt
# 2164  c05bf7a7-8973-4aba-812b-b76f3e3e22d3   10/1/87 0:00         NaN
# 2165  df15d76f-245d-46c2-8a76-4d95cdc515bf  10/13/33 0:00         NaN
# 2186  2d7de426-21c7-49da-9653-c35d58fdc705  11/15/67 0:00         NaN
# 2187  9a9175d7-757b-4a1f-8be0-c992e7d39bf3   11/2/67 0:00         NaN
# 2188  fb710eba-10d7-4160-abe7-412c4a09f825  11/20/67 0:00         NaN
# ...                                    ...            ...         ...
# 2557  89307c5b-830c-4b66-b18d-aae408e8179a            NaN         NaN
# 2558  deb86930-6997-42fe-a742-c4627261a60a            NaN         NaN
# 2559  6942f9e6-84b2-4c4c-8c0d-55761ee1ec0e            NaN         NaN
# 2560  1403daa6-c2ab-4449-a7f0-c4efcc30fae4            NaN         NaN
# 2561  8effc458-b773-4c4b-b1cf-0938d97b88a3            NaN         NaN
#
# [104 rows x 3 columns]

# %%
#Subset projects with 7 digits 
sonoma_apn_seven_dig = sonoma_projects[['apn']][sonoma_projects['apn'].str.len() == 7]

# %%
#Prepend with two zeros
sonoma_apn_seven_dig['apn_fmt'] = '00' + sonoma_apn_seven_dig['apn']

# %%
sonoma_apn_seven_dig
# Out:
#           apn    apn_fmt
# 112   5192025  005192025
# 114   6071009  006071009
# 115   6241024  006241024
# 116   6450010  006450010
# 117   6562019  006562019
# ...       ...        ...
# 3346  9131009  009131009
# 3347  9272003  009272003
# 3348  9293001  009293001
# 3349  9344005  009344005
# 3783  7610029  007610029
#
# [108 rows x 2 columns]

# %%
sonoma_apn_seven_dig['apn_fmt'] = (sonoma_apn_seven_dig['apn_fmt'].str[0:3] + 
                                 '-' +
                                 sonoma_apn_seven_dig['apn_fmt'].str[3:6] +
                                 '-' +
                                 sonoma_apn_seven_dig['apn_fmt'].str[6:])

# %%
sonoma_apn_seven_dig
# Out:
#           apn      apn_fmt
# 112   5192025  005-192-025
# 114   6071009  006-071-009
# 115   6241024  006-241-024
# 116   6450010  006-450-010
# 117   6562019  006-562-019
# ...       ...          ...
# 3346  9131009  009-131-009
# 3347  9272003  009-272-003
# 3348  9293001  009-293-001
# 3349  9344005  009-344-005
# 3783  7610029  007-610-029
#
# [108 rows x 2 columns]

# %%
#Update original dataframe with updated apns
sonoma_projects['mtc_apn_fmt'].update(sonoma_apn_seven_dig['apn_fmt'])

# %%
sonoma_projects[['apn','mtc_apn_fmt']][sonoma_projects['mtc_apn_fmt'].isnull()].shape
# Out:
# (104, 2)

# %%
#Upsert formatted apns to socrata
upsert_df_socrata(sonoma_projects[['mtc_id','mtc_apn_fmt']],apr_id)
# Out:
# upserting data to Socrata in 1 chunks of 3787 rows each
# upserted chunk 0
# data upserted to briv-ikjp
# took 2.9269 seconds

# %% [markdown]
# ## Join to parcels by apn

# %%
#Subset projects to required fields
geocode_types = ['APPROXIMATE','GEOMETRIC_CENTER','NOT_GEOCODED']
sonoma_projects_sub = (sonoma_projects[['mtc_id','apn','mtc_apn_fmt']][sonoma_projects['mtc_geocode_type']
                                                                       .isin(geocode_types)]
                       .copy())

# %%
sonoma_projects_parcels = pd.merge(sonoma_projects_sub,
                                  parcels_sonoma,
                                  left_on ='mtc_apn_fmt',
                                  right_on='apn',
                                  how='left',
                                  indicator=True)

# %%
sonoma_projects_parcels[sonoma_projects_parcels['_merge'] == 'both'].shape
# Out:
# (114, 50)

# %%
sonoma_projects_parcels.shape
# Out:
# (216, 50)

# %%
sonoma_projects_parcels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216 entries, 0 to 215
# Data columns (total 50 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mtc_id       216 non-null    object
#  1   apn_x        216 non-null    object
#  2   mtc_apn_fmt  184 non-null    object
#  3   objectid     114 non-null    float64
#  4   apn_y        114 non-null    object
#  5   apn2         114 non-null    object
#  6   state        114 non-null    object
#  7   county       114 non-null    object
#  8   fips         114 non-null    object
#  9   sit_hse_nu   40 non-null     object
#  10  sit_dir      0 non-null      object
#  11  sit_str_na   50 non-null     object
#  12  sit_str_sf   50 non-null     object
#  13  sit_full_s   50 non-null     object
#  14  sit_city     50 non-null     object
#  15  sit_state    50 non-null     object
#  16  sit_zip      49 non-null     object
#  17  sit_zip4     36 non-null     object
#  18  land_value   114 non-null    float64
#  19  impr_value   114 non-null    float64
#  20  tot_value    114 non-null    float64
#  21  assmt_year   114 non-null    float64
#  22  rec_date     24 non-null     object
#  23  sales_pric   114 non-null    float64
#  24  year_built   114 non-null    float64
#  25  std_land_u   50 non-null     float64
#  26  lot_size     114 non-null    float64
#  27  bldg_area    114 non-null    float64
#  28  deed_dscr    8 non-null      object
#  29  no_of_stor   24 non-null     object
#  30  no_of_unit   114 non-null    float64
#  31  bedrooms     114 non-null    float64
#  32  bathrooms    114 non-null    float64
#  33  shortowner   50 non-null     object
#  34  owner2       4 non-null      object
#  35  ownaddress   49 non-null     object
#  36  ownaddres2   0 non-null      float64
#  37  ownctystzp   50 non-null     object
#  38  xcoord       114 non-null    float64
#  39  ycoord       114 non-null    float64
#  40  minx         114 non-null    float64
#  41  miny         114 non-null    float64
#  42  maxx         114 non-null    float64
#  43  maxy         114 non-null    float64
#  44  attdate      50 non-null     object
#  45  version      114 non-null    object
#  46  quantarium   50 non-null     object
#  47  gpid         114 non-null    object
#  48  geometry     114 non-null    object
#  49  _merge       216 non-null    category
# dtypes: category(1), float64(20), object(29)
# memory usage: 84.7+ KB

# %%
sonoma_projects_parcels_sub = sonoma_projects_parcels[['mtc_id',
                                                       'mtc_apn_fmt',
                                                       'xcoord',
                                                       'ycoord',
                                                       '_merge']][sonoma_projects_parcels['_merge'] == 'both'].copy()

# %%
sonoma_projects_parcels_sub
# Out:
#                                    mtc_id  mtc_apn_fmt   xcoord   ycoord  \
# 13   64d9a665-fb38-48a2-8172-071fe5e69534  144-450-002 -122.704  38.3202
# 23   1ad6da8a-6d32-4ea5-a57a-4efb30e501e6  089-300-007 -122.876  38.6229
# 26   ee196048-9612-4657-8892-1d34daa3a56f  159-610-054 -122.676  38.3245
# 27   d4208131-6f04-46be-ac8d-1b337a53496f  159-610-055 -122.676  38.3246
# 28   2d3f91d9-a65a-48fc-9e35-7d429b48e004  159-620-097 -122.674  38.3463
# ..                                    ...          ...      ...      ...
# 210  14fc32bb-ea34-482a-ab3d-52964b05a219  163-320-085 -122.792  38.5298
# 211  05764f97-0587-42b3-9dc4-30c44fdb3a79  163-320-086 -122.792  38.5299
# 212  bde40512-27e1-4167-8ee7-dbe09aca9b50  163-320-087 -122.792  38.5301
# 214  687092a9-3a24-4ad4-a8c1-4122c50a9e31  117-020-039 -122.997  38.7653
# 215  857da0d2-3b3b-4c3a-8721-5be8158ec28b  159-570-032 -122.679  38.3483
#
#     _merge
# 13    both
# 23    both
# 26    both
# 27    both
# 28    both
# ..     ...
# 210   both
# 211   both
# 212   both
# 214   both
# 215   both
#
# [114 rows x 5 columns]

# %%
#Create geodataframe from lat long coords
sonoma_geo = gp.GeoDataFrame(sonoma_projects_parcels_sub,
                                  geometry=gp.points_from_xy(sonoma_projects_parcels_sub['xcoord'],
                                                             sonoma_projects_parcels_sub['ycoord']),
                                  crs="EPSG:4326")

# %%
sonoma_geo.head(5)
# Out:
#                                   mtc_id  mtc_apn_fmt   xcoord   ycoord  \
# 13  64d9a665-fb38-48a2-8172-071fe5e69534  144-450-002 -122.704  38.3202
# 23  1ad6da8a-6d32-4ea5-a57a-4efb30e501e6  089-300-007 -122.876  38.6229
# 26  ee196048-9612-4657-8892-1d34daa3a56f  159-610-054 -122.676  38.3245
# 27  d4208131-6f04-46be-ac8d-1b337a53496f  159-610-055 -122.676  38.3246
# 28  2d3f91d9-a65a-48fc-9e35-7d429b48e004  159-620-097 -122.674  38.3463
#
#    _merge                     geometry
# 13   both  POINT (-122.70400 38.32020)
# 23   both  POINT (-122.87600 38.62290)
# 26   both  POINT (-122.67600 38.32450)
# 27   both  POINT (-122.67600 38.32460)
# 28   both  POINT (-122.67400 38.34630)

# %%
sonoma_geo['mtc_wkt'] = sonoma_geo['geometry'].map(lambda x: x.wkt)

# %%
#Rename columns to match final schema
sonoma_geo.rename(columns={'xcoord':'mtc_long','ycoord':'mtc_lat'},inplace=True)

# %%
#Add mtc_mapped column and set to True
sonoma_geo['mtc_mapped'] = True

# %%
#Add mtc_geocode_type and set to APN_MATCH
sonoma_geo['mtc_geocode_type'] = 'APN_MATCH'

# %%
sonoma_geo.head(5)
# Out:
#                                   mtc_id  mtc_apn_fmt  mtc_long  mtc_lat  \
# 13  64d9a665-fb38-48a2-8172-071fe5e69534  144-450-002  -122.704  38.3202
# 23  1ad6da8a-6d32-4ea5-a57a-4efb30e501e6  089-300-007  -122.876  38.6229
# 26  ee196048-9612-4657-8892-1d34daa3a56f  159-610-054  -122.676  38.3245
# 27  d4208131-6f04-46be-ac8d-1b337a53496f  159-610-055  -122.676  38.3246
# 28  2d3f91d9-a65a-48fc-9e35-7d429b48e004  159-620-097  -122.674  38.3463
#
#    _merge                     geometry                   mtc_wkt  mtc_mapped  \
# 13   both  POINT (-122.70400 38.32020)  POINT (-122.704 38.3202)        True
# 23   both  POINT (-122.87600 38.62290)  POINT (-122.876 38.6229)        True
# 26   both  POINT (-122.67600 38.32450)  POINT (-122.676 38.3245)        True
# 27   both  POINT (-122.67600 38.32460)  POINT (-122.676 38.3246)        True
# 28   both  POINT (-122.67400 38.34630)  POINT (-122.674 38.3463)        True
#
#    mtc_geocode_type
# 13        APN_MATCH
# 23        APN_MATCH
# 26        APN_MATCH
# 27        APN_MATCH
# 28        APN_MATCH

# %%
#Upsert updated records to socrata
final_columns = ['mtc_id','mtc_apn_fmt','mtc_long','mtc_lat','mtc_mapped','mtc_geocode_type','mtc_wkt']
upsert_df_socrata(sonoma_geo[final_columns],apr_id)
# Out:
# upserting data to Socrata in 1 chunks of 114 rows each
# upserted chunk 0
# data upserted to briv-ikjp
# took 1.4472 seconds
